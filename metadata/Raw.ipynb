# %%
import scanpy as sc

# %%
adata= sc.read_h5ad('/nfs/team298/sm54/developmental_data_old_versions/fetal_liver_alladata.h5ad')

# %%
adata.obs['cell.labels'].value_counts()
# Out:
# cell.labels
# Mid Erythroid                    27000
# Kupffer Cell                     24841
# Early Erythroid                  11985
# NK                                6706
# Mono-Mac                          6590
# Megakaryocyte                     3983
# DC2                               3954
# HSC_MPP                           3439
# Endothelial cell                  3348
# Late Erythroid                    3180
# Monocyte                          2586
# Hepatocyte                        2479
# ILC precursor                     1726
# Fibroblast                        1713
# pro-B cell                        1383
# MEMP                              1342
# pre-B cell                        1332
# Mast cell                         1308
# B cell                            1079
# Early lymphoid_T lymphocyte        767
# Neutrophil-myeloid progenitor      658
# Monocyte precursor                 350
# DC1                                336
# DC precursor                       330
# ...

# %%
macs_liver=adata[adata.obs['cell.labels'].isin(['Monocyte','Monocyte precursor','VCAM1+ EI macrophage','Mono-Mac','Kupffer Cell'])]

# %%
macs_liver.write_h5ad('/nfs/team298/sm54/BoneAtlasProject/data/macs_liver.h5ad')

# %%
macs_liver
# Out:
# View of AnnData object with n_obs × n_vars = 34528 × 27080
#     obs: 'nGene', 'nUMI', 'orig.ident', 'percent.mito', 'fetal.ids', 'sort.ids', 'tissue', 'lanes', 'stages', 'sample.type', 'gender', 'AnnatomicalPart', 'doublets', 'cell.labels', 'combined.labels', 'batch', 'sample', 'n_counts'
#     obsm: 'X_fdg', 'X_tsne', 'X_umap'
