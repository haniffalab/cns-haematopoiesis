# %% [markdown]
# # Read in required packages

# %%
import sys

import scanpy as sc
import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib as mpl
import scipy
import scrublet as scr
#import scvi
import hashlib

from matplotlib import rcParams
rcParams['pdf.fonttype'] = 42 # enables correct plotting of text
import seaborn as sns
import anndata
import os
import gc
import warnings

# %%
pwd
# Out:
# '/nfs/users/nfs_s/sm54/repos/cns-haematopoiesis/analysis/01_preprocess_scRNAseq'

# %% [markdown]
# # Functions

# %%
# Code provided by Vitalii

def read_10x_output(smp_list, metadata=None, type = 'raw'):
    import os
    
    #Writing output from separate samples, processed using CellRanger, into a dictionary of Scanpy objects:
    ad = {}

    #Generate AnnData for each sample
    for sample_name in smp_list:
        path = sample_name
        for i in os.listdir(path):
            if type in i and 'h5' in i:
                file = f"{sample_name}_knee_FPR_0.01_filtered.h5"
                ad[sample_name] = sc.read_10x_h5(sample_name +'/'+file)
                scrub = scr.Scrublet(ad[sample_name].X.copy())
                doublet_scores, predicted_doublets = scrub.scrub_doublets()
                ad[sample_name].obs['doublet_scores'] = doublet_scores
                ad[sample_name].obs['predicted_doublets'] = predicted_doublets
                ad[sample_name].var['ENSEMBL'] = ad[sample_name].var.index
                ad[sample_name].var.rename(columns = {'gene_ids':'SYMBOL'}, inplace = True)
                ad[sample_name].var.index = ad[sample_name].var['SYMBOL']
                ad[sample_name].var_names_make_unique() 
                ad[sample_name].obs['sample_id'] = sample_name
                ad[sample_name].obs['barcode'] = ad[sample_name].obs_names
                ad[sample_name].obs_names = ad[sample_name].obs['barcode']+"_"+ad[sample_name].obs['sample_id']

    #Merge AnnData objects from all the samples together    
    from scipy.sparse import vstack
    stack = vstack([ad[x].X for x in smp_list]) # stack data
    adata = sc.AnnData(stack, var = ad[smp_list[0]].var)
    adata.obs = pd.concat([ad[x].obs for x in smp_list], axis = 0)
    
    for c in adata.obs.columns:
        adata.obs[c] = adata.obs[c].astype('str')
    adata.obs =  adata.obs.copy()

    return adata, ad

# %%
metadata= pd.read_csv("/lustre/scratch126/cellgen/team298/sm54/Data_Integration/Integrated_Object/metadata/metadata_harmonised.csv")

# %%
cd /lustre/scratch126/cellgen/team205/sharedData/kt21/all_multiome_cellbender
# Out:
# /lustre/scratch126/cellgen/team205/sharedData/kt21/all_multiome_cellbender

# %%
metadata
# Out:
#       Organ                                 Run_ID            Age  \
# 0     Skull  HCA_BN_F12627470_and_HCA_BN_F12605339  5.8, 7.6, 8.3
# 1     Skull  HCA_BN_F12627471_and_HCA_BN_F12605340       7.6, 8.3
# 2     Skull  HCA_BN_F12627472_and_HCA_BN_F12605341       5.8, 8.3
# 3     Skull  HCA_BN_F12627473_and_HCA_BN_F12605342       7.6, 8.3
# 4     Skull  HCA_BN_F12874040_and_HCA_BN_F12865672            9.4
# ..      ...                                    ...            ...
# 127  Spine                41865_SB_200532_11018320             17
# 128  Spine                41865_SB_200532_11018321             17
# 129  Spine                41865_SB_200532_11018322             17
# 130  Spine                41865_SB_200532_11018323             17
# 131  Spine                41865_SB_200532_11018324             17
#
#     Anatomical_Site     Donor_ID    Technology   \
# 0              knee  multiplexed   10X_multiome
# 1               hip  multiplexed   10X_multiome
# 2      hip/shoulder  multiplexed   10X_multiome
# 3          shoulder  multiplexed   10X_multiome
# 4               hip         2384   10X_multiome
# ..              ...          ...            ...
# 127       cervical     HDBR15948  10X_scRNA-seq
# 128       thoracic     HDBR15948  10X_scRNA-seq
# 129       thoracic     HDBR15948  10X_scRNA-seq
# 130         lumbar     HDBR15948  10X_scRNA-seq
# 131          sacral    HDBR15948  10X_scRNA-seq
#
#                                             iRODs path  \
# 0    /seq/illumina/cellranger-arc/cellranger-arc201...
# 1    /seq/illumina/cellranger-arc/cellranger-arc201...
# 2    /seq/illumina/cellranger-arc/cellranger-arc201...
# 3    /seq/illumina/cellranger-arc/cellranger-arc201...
# 4    /seq/illumina/cellranger-arc/cellranger-arc201...
# ..                                                 ...
# 127  /seq/illumina/runs/41/41865/cellranger/cellran...
# 128  /seq/illumina/runs/41/41865/cellranger/cellran...
# 129  /seq/illumina/runs/41/41865/cellranger/cellran...
# 130  /seq/illumina/runs/41/41865/cellranger/cellran...
# 131  /seq/illumina/runs/41/41865/cellranger/cellran...
#
#                                             Farm Path   \
# 0    /lustre/scratch126/cellgen/team298/sm54/Data_I...
# 1    /lustre/scratch126/cellgen/team298/sm54/Data_I...
# 2    /lustre/scratch126/cellgen/team298/sm54/Data_I...
# 3    /lustre/scratch126/cellgen/team298/sm54/Data_I...
# 4    /lustre/scratch126/cellgen/team298/sm54/Data_I...
# ..                                                 ...
# 127  /lustre/scratch126/cellgen/team298/sm54/Data_I...
# 128  /lustre/scratch126/cellgen/team298/sm54/Data_I...
# 129  /lustre/scratch126/cellgen/team298/sm54/Data_I...
# 130  /lustre/scratch126/cellgen/team298/sm54/Data_I...
# 131  /lustre/scratch126/cellgen/team298/sm54/Data_I...
#
#                                 CellBender_Output_Path  \
# 0    /lustre/scratch126/cellgen/team205/sharedData/...
# 1    /lustre/scratch126/cellgen/team205/sharedData/...
# 2    /lustre/scratch126/cellgen/team205/sharedData/...
# 3    /lustre/scratch126/cellgen/team205/sharedData/...
# 4    /lustre/scratch126/cellgen/team205/sharedData/...
# ..                                                 ...
# 127  /lustre/scratch126/cellgen/team298/sm54/Data_I...
# 128  /lustre/scratch126/cellgen/team298/sm54/Data_I...
# 129  /lustre/scratch126/cellgen/team298/sm54/Data_I...
# 130  /lustre/scratch126/cellgen/team298/sm54/Data_I...
# 131  /lustre/scratch126/cellgen/team298/sm54/Data_I...
#
#     Demultiplexed_Barcodes_Location
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 127                             NaN
# 128                             NaN
# 129                             NaN
# 130                             NaN
# 131                             NaN
#
# [132 rows x 10 columns]

# %%
arr = os.listdir()

sample_list= metadata["Run_ID"].tolist()

sample_list = [x for x in sample_list if str(x) != 'nan']


filter_data = [x for x in arr if
              any(y in x for y in sample_list)]

# %%
filter_data
# Out:
# ['HCA_BN_F13109713_and_HCA_BN_F13101383',
#  'HCA_BN_F12863835_and_HCA_BN_F12865000',
#  'HCA_BN_F12808062_and_HCA_BN_F12803238',
#  'HCA_BN_F12482359_and_HCA_BN_F12477271',
#  'HCA_BRA_F13774555_and_HCA_BRA_F13852282',
#  'HCA_BN_F13177436_and_HCA_BN_F13177209',
#  'HCA_BN_F12482364_and_HCA_BN_F12477276',
#  'HCA_BN_F13177435_and_HCA_BN_F13177208',
#  'HCA_BN_F12874046_and_HCA_BN_F12865678',
#  'HCA_BN_F12482365_and_HCA_BN_F12477277',
#  'HCA_BN_F13109711_and_HCA_BN_F13101381',
#  'HCA_BN_F12874040_and_HCA_BN_F12865672',
#  'HCA_BN_F13109712_and_HCA_BN_F13101382',
#  'HCA_BRA_F13168992_and_HCA_BRA_F13168608',
#  'HCA_BN_F12874042_and_HCA_BN_F12865674',
#  'HCA_BN_F12874043_and_HCA_BN_F12865675',
#  'HCA_BRA_F13168988_and_HCA_BRA_F13168604',
#  'HCA_BN_F12482366_and_HCA_BN_F12477278',
#  'HCA_BRA_F13774556_and_HCA_BRA_F13852283',
#  'HCA_BRA_F13168989_and_HCA_BRA_F13168605',
#  'HCA_BN_F12966456_and_HCA_BN_F12951832',
#  'HCA_BN_F12808059_and_HCA_BN_F12803235',
#  'HCA_BN_F12922483_and_HCA_BN_F12918721',
#  'HCA_BN_F12922481_and_HCA_BN_F12918719',
#  'HCA_BRA_F13774552_and_HCA_BRA_F13768422',
#  'HCA_BN_F13177437_and_HCA_BN_F13177210',
#  'HCA_BN_F12863837_and_HCA_BN_F12865002',
#  'HCA_BRA_F13168991_and_HCA_BRA_F13168607',
#  'HCA_BN_F13177434_and_HCA_BN_F13177207',
#  'HCA_BN_F12808058_and_HCA_BN_F12803234',
#  'HCA_BN_F13109719_and_HCA_BN_F13128947',
#  'HCA_BN_F13109714_and_HCA_BN_F13128942',
#  'HCA_BN_F12966458_and_HCA_BN_F12951834',
#  'HCA_BN_F12808060_and_HCA_BN_F12803236',
#  'HCA_BN_F12874047_and_HCA_BN_F12865679',
#  'HCA_BN_F13109718_and_HCA_BN_F13128946',
#  'HCA_BN_F12482360_and_HCA_BN_F12477272',
#  'HCA_BRA_F13774554_and_HCA_BRA_F13852281',
#  'HCA_BN_F12966460_and_HCA_BN_F12951836',
#  'HCA_BRA_F13168990_and_HCA_BRA_F13168606',
#  'HCA_BN_F12922486_and_HCA_BN_F12918724',
#  'HCA_BN_F12808061_and_HCA_BN_F12803237',
#  'HCA_BN_F12966461_and_HCA_BN_F12951837',
#  'HCA_BN_F12966459_and_HCA_BN_F12951835',
#  'HCA_BN_F12627470_and_HCA_BN_F12605339',
#  'HCA_BN_F12922484_and_HCA_BN_F12918722',
#  'HCA_BRA_F13774551_and_HCA_BRA_F13768421',
#  'HCA_BN_F12922482_and_HCA_BN_F12918720',
#  'HCA_BN_F12874045_and_HCA_BN_F12865677',
#  'HCA_BN_F12482361_and_HCA_BN_F12477273',
#  'HCA_BN_F12627471_and_HCA_BN_F12605340',
#  'HCA_BRA_F13774553_and_HCA_BRA_F13768423',
#  'HCA_BN_F13109710_and_HCA_BN_F13101380',
#  'HCA_BN_F12627473_and_HCA_BN_F12605342',
#  'HCA_BN_F13109715_and_HCA_BN_F13128943',
#  'HCA_BN_F12874041_and_HCA_BN_F12865673',
#  'HCA_BN_F12863836_and_HCA_BN_F12865001',
#  'HCA_BN_F12627472_and_HCA_BN_F12605341',
#  'HCA_BN_F12922487_and_HCA_BN_F12918725',
#  'HCA_BRA_F13168993_and_HCA_BRA_F13168609',
#  'HCA_BN_F12922485_and_HCA_BN_F12918723',
#  'HCA_BN_F12966455_and_HCA_BN_F12951831',
#  'HCA_BN_F12966457_and_HCA_BN_F12951833',
#  'HCA_BN_F12874044_and_HCA_BN_F12865676',
#  'HCA_BN_F12482362_and_HCA_BN_F12477274',
#  'HCA_BN_F12482363_and_HCA_BN_F12477275']

# %% [markdown]
# # Skull and meninges

# %%
len(filter_data)
# Out:
# 66

# %%
filter_data.remove('HCA_BRA_F13774552_and_HCA_BRA_F13768422')

# %%
len(filter_data)
# Out:
# 65

# %%
import warnings
warnings.filterwarnings('ignore')

adata, ad_list = read_10x_output(
    smp_list=filter_data,
    
    type='filtered'
)
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.77
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 4.8%
# Elapsed time: 73.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.77
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 4.8%
# Elapsed time: 76.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.77
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 4.8%
# Elapsed time: 75.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.77
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 4.8%
# Elapsed time: 74.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.64
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 79.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.64
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 80.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.64
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 85.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.64
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 84.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.64
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 82.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.64
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 79.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.64
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 80.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.11
# Detected doublet rate = 34.2%
# Estimated detectable doublet fraction = 79.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 43.2%
# Elapsed time: 39.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.11
# Detected doublet rate = 34.2%
# Estimated detectable doublet fraction = 79.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 43.2%
# Elapsed time: 37.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.11
# Detected doublet rate = 34.2%
# Estimated detectable doublet fraction = 79.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 43.2%
# Elapsed time: 37.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.11
# Detected doublet rate = 34.2%
# Estimated detectable doublet fraction = 79.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 43.2%
# Elapsed time: 38.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 11.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 11.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 12.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 12.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.19
# Detected doublet rate = 12.5%
# Estimated detectable doublet fraction = 54.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 23.0%
# Elapsed time: 32.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.19
# Detected doublet rate = 12.5%
# Estimated detectable doublet fraction = 54.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 23.0%
# Elapsed time: 33.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.19
# Detected doublet rate = 12.5%
# Estimated detectable doublet fraction = 54.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 23.0%
# Elapsed time: 32.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.19
# Detected doublet rate = 12.5%
# Estimated detectable doublet fraction = 54.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 23.0%
# Elapsed time: 31.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 36.4%
# Elapsed time: 32.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 36.4%
# Elapsed time: 30.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 36.4%
# Elapsed time: 30.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 36.4%
# Elapsed time: 30.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.61
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 28.6%
# Elapsed time: 8.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.61
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 28.6%
# Elapsed time: 8.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.61
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 28.6%
# Elapsed time: 8.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.61
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 28.6%
# Elapsed time: 7.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 6.8%
# Estimated detectable doublet fraction = 30.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 22.3%
# Elapsed time: 32.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 6.8%
# Estimated detectable doublet fraction = 30.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 22.3%
# Elapsed time: 31.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 6.8%
# Estimated detectable doublet fraction = 30.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 22.3%
# Elapsed time: 30.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.25
# Detected doublet rate = 6.8%
# Estimated detectable doublet fraction = 30.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 22.3%
# Elapsed time: 31.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 16.7%
# Elapsed time: 52.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 16.7%
# Elapsed time: 51.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 16.7%
# Elapsed time: 49.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.48
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 16.7%
# Elapsed time: 51.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.60
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 10.5%
# Elapsed time: 14.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.60
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 10.5%
# Elapsed time: 15.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.60
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 10.5%
# Elapsed time: 14.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.60
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 10.5%
# Elapsed time: 17.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.06
# Detected doublet rate = 87.4%
# Estimated detectable doublet fraction = 97.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 89.4%
# Elapsed time: 53.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.06
# Detected doublet rate = 87.4%
# Estimated detectable doublet fraction = 97.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 89.4%
# Elapsed time: 55.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.06
# Detected doublet rate = 87.4%
# Estimated detectable doublet fraction = 97.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 89.4%
# Elapsed time: 56.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.06
# Detected doublet rate = 87.4%
# Estimated detectable doublet fraction = 97.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 89.4%
# Elapsed time: 54.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.14
# Detected doublet rate = 29.4%
# Estimated detectable doublet fraction = 66.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 44.0%
# Elapsed time: 45.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.14
# Detected doublet rate = 29.4%
# Estimated detectable doublet fraction = 66.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 44.0%
# Elapsed time: 42.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.14
# Detected doublet rate = 29.4%
# Estimated detectable doublet fraction = 66.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 44.0%
# Elapsed time: 44.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.14
# Detected doublet rate = 29.4%
# Estimated detectable doublet fraction = 66.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 44.0%
# Elapsed time: 45.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.04
# Detected doublet rate = 88.2%
# Estimated detectable doublet fraction = 98.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 89.3%
# Elapsed time: 54.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.04
# Detected doublet rate = 88.2%
# Estimated detectable doublet fraction = 98.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 89.3%
# Elapsed time: 55.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.04
# Detected doublet rate = 88.2%
# Estimated detectable doublet fraction = 98.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 89.3%
# Elapsed time: 54.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.04
# Detected doublet rate = 88.2%
# Estimated detectable doublet fraction = 98.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 89.3%
# Elapsed time: 55.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 2.0%
# Estimated detectable doublet fraction = 18.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 11.1%
# Elapsed time: 8.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 2.0%
# Estimated detectable doublet fraction = 18.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 11.1%
# Elapsed time: 9.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 2.0%
# Estimated detectable doublet fraction = 18.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 11.1%
# Elapsed time: 9.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 2.0%
# Estimated detectable doublet fraction = 18.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 11.1%
# Elapsed time: 9.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 33.3%
# Elapsed time: 45.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 33.3%
# Elapsed time: 44.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 33.3%
# Elapsed time: 45.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 33.3%
# Elapsed time: 44.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 16.2%
# Estimated detectable doublet fraction = 54.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 29.9%
# Elapsed time: 30.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 16.2%
# Estimated detectable doublet fraction = 54.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 29.9%
# Elapsed time: 30.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 16.2%
# Estimated detectable doublet fraction = 54.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 29.9%
# Elapsed time: 30.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 16.2%
# Estimated detectable doublet fraction = 54.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 29.9%
# Elapsed time: 31.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.13
# Detected doublet rate = 25.4%
# Estimated detectable doublet fraction = 73.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 34.7%
# Elapsed time: 13.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.13
# Detected doublet rate = 25.4%
# Estimated detectable doublet fraction = 73.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 34.7%
# Elapsed time: 13.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.13
# Detected doublet rate = 25.4%
# Estimated detectable doublet fraction = 73.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 34.7%
# Elapsed time: 13.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.13
# Detected doublet rate = 25.4%
# Estimated detectable doublet fraction = 73.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 34.7%
# Elapsed time: 13.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.76
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 31.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.76
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 31.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.76
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 31.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.76
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 30.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.76
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 31.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.76
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 31.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.76
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 32.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Warning: failed to automatically identify doublet score threshold. Run `call_doublets` with user-specified threshold.
# Elapsed time: 33.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Warning: failed to automatically identify doublet score threshold. Run `call_doublets` with user-specified threshold.
# Elapsed time: 35.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Warning: failed to automatically identify doublet score threshold. Run `call_doublets` with user-specified threshold.
# Elapsed time: 34.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Warning: failed to automatically identify doublet score threshold. Run `call_doublets` with user-specified threshold.
# Elapsed time: 33.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 11.8%
# Estimated detectable doublet fraction = 53.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 22.3%
# Elapsed time: 36.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 11.8%
# Estimated detectable doublet fraction = 53.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 22.3%
# Elapsed time: 38.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 11.8%
# Estimated detectable doublet fraction = 53.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 22.3%
# Elapsed time: 37.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 11.8%
# Estimated detectable doublet fraction = 53.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 22.3%
# Elapsed time: 39.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.12
# Detected doublet rate = 34.4%
# Estimated detectable doublet fraction = 80.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 42.9%
# Elapsed time: 37.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.12
# Detected doublet rate = 34.4%
# Estimated detectable doublet fraction = 80.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 42.9%
# Elapsed time: 38.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.12
# Detected doublet rate = 34.4%
# Estimated detectable doublet fraction = 80.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 42.9%
# Elapsed time: 38.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.12
# Detected doublet rate = 34.4%
# Estimated detectable doublet fraction = 80.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 42.9%
# Elapsed time: 38.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 100.0%
# Elapsed time: 11.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 100.0%
# Elapsed time: 11.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 100.0%
# Elapsed time: 11.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 100.0%
# Elapsed time: 13.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 33.3%
# Elapsed time: 35.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 33.3%
# Elapsed time: 34.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 33.3%
# Elapsed time: 35.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 33.3%
# Elapsed time: 35.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 33.3%
# Elapsed time: 35.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 33.3%
# Elapsed time: 35.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.54
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 33.3%
# Elapsed time: 35.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 30.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 30.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 29.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 31.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 10.0%
# Estimated detectable doublet fraction = 33.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.1%
# Elapsed time: 48.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 10.0%
# Estimated detectable doublet fraction = 33.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.1%
# Elapsed time: 46.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 10.0%
# Estimated detectable doublet fraction = 33.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.1%
# Elapsed time: 48.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 10.0%
# Estimated detectable doublet fraction = 33.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.1%
# Elapsed time: 47.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 10.0%
# Estimated detectable doublet fraction = 33.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.1%
# Elapsed time: 49.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 10.0%
# Estimated detectable doublet fraction = 33.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.1%
# Elapsed time: 48.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 10.0%
# Estimated detectable doublet fraction = 33.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.1%
# Elapsed time: 46.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 6.5%
# Elapsed time: 27.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 6.5%
# Elapsed time: 27.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 6.5%
# Elapsed time: 26.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 6.5%
# Elapsed time: 26.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.13
# Detected doublet rate = 21.6%
# Estimated detectable doublet fraction = 69.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.9%
# Elapsed time: 12.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.13
# Detected doublet rate = 21.6%
# Estimated detectable doublet fraction = 69.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.9%
# Elapsed time: 11.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.13
# Detected doublet rate = 21.6%
# Estimated detectable doublet fraction = 69.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.9%
# Elapsed time: 12.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.13
# Detected doublet rate = 21.6%
# Estimated detectable doublet fraction = 69.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.9%
# Elapsed time: 11.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 12.5%
# Elapsed time: 24.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 12.5%
# Elapsed time: 25.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 12.5%
# Elapsed time: 26.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 12.5%
# Elapsed time: 25.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 35.3%
# Elapsed time: 24.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 35.3%
# Elapsed time: 24.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 35.3%
# Elapsed time: 24.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 35.3%
# Elapsed time: 23.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 55.6%
# Elapsed time: 13.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 55.6%
# Elapsed time: 10.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 55.6%
# Elapsed time: 10.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 55.6%
# Elapsed time: 10.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 34.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 35.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 35.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 35.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 34.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 34.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 36.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 14.3%
# Elapsed time: 24.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 14.3%
# Elapsed time: 24.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 14.3%
# Elapsed time: 24.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 14.3%
# Elapsed time: 24.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.11
# Detected doublet rate = 31.3%
# Estimated detectable doublet fraction = 78.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 40.2%
# Elapsed time: 16.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.11
# Detected doublet rate = 31.3%
# Estimated detectable doublet fraction = 78.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 40.2%
# Elapsed time: 16.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.11
# Detected doublet rate = 31.3%
# Estimated detectable doublet fraction = 78.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 40.2%
# Elapsed time: 16.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.11
# Detected doublet rate = 31.3%
# Estimated detectable doublet fraction = 78.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 40.2%
# Elapsed time: 16.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 41.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 41.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# ...
# Estimated detectable doublet fraction = 40.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.0%
# Elapsed time: 47.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 12.1%
# Estimated detectable doublet fraction = 40.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.0%
# Elapsed time: 47.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 34.4%
# Elapsed time: 23.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 34.4%
# Elapsed time: 23.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 34.4%
# Elapsed time: 22.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 34.4%
# Elapsed time: 23.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 18.7%
# Estimated detectable doublet fraction = 60.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.9%
# Elapsed time: 51.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 18.7%
# Estimated detectable doublet fraction = 60.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.9%
# Elapsed time: 54.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 18.7%
# Estimated detectable doublet fraction = 60.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.9%
# Elapsed time: 54.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 18.7%
# Estimated detectable doublet fraction = 60.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.9%
# Elapsed time: 51.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 18.7%
# Estimated detectable doublet fraction = 60.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.9%
# Elapsed time: 53.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 18.7%
# Estimated detectable doublet fraction = 60.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.9%
# Elapsed time: 55.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 18.7%
# Estimated detectable doublet fraction = 60.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 30.9%
# Elapsed time: 53.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.15
# Detected doublet rate = 22.8%
# Estimated detectable doublet fraction = 69.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 32.9%
# Elapsed time: 31.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.15
# Detected doublet rate = 22.8%
# Estimated detectable doublet fraction = 69.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 32.9%
# Elapsed time: 31.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.15
# Detected doublet rate = 22.8%
# Estimated detectable doublet fraction = 69.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 32.9%
# Elapsed time: 31.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.15
# Detected doublet rate = 22.8%
# Estimated detectable doublet fraction = 69.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 32.9%
# Elapsed time: 31.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 19.9%
# Estimated detectable doublet fraction = 63.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.3%
# Elapsed time: 42.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 19.9%
# Estimated detectable doublet fraction = 63.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.3%
# Elapsed time: 42.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 19.9%
# Estimated detectable doublet fraction = 63.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.3%
# Elapsed time: 42.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 19.9%
# Estimated detectable doublet fraction = 63.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.3%
# Elapsed time: 42.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 19.9%
# Estimated detectable doublet fraction = 63.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.3%
# Elapsed time: 42.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 19.9%
# Estimated detectable doublet fraction = 63.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.3%
# Elapsed time: 41.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 19.9%
# Estimated detectable doublet fraction = 63.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.3%
# Elapsed time: 41.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 12.6%
# Estimated detectable doublet fraction = 39.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.9%
# Elapsed time: 51.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 12.6%
# Estimated detectable doublet fraction = 39.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.9%
# Elapsed time: 51.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 12.6%
# Estimated detectable doublet fraction = 39.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.9%
# Elapsed time: 51.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 12.6%
# Estimated detectable doublet fraction = 39.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.9%
# Elapsed time: 51.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 12.6%
# Estimated detectable doublet fraction = 39.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.9%
# Elapsed time: 51.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 12.6%
# Estimated detectable doublet fraction = 39.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.9%
# Elapsed time: 52.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.22
# Detected doublet rate = 12.6%
# Estimated detectable doublet fraction = 39.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.9%
# Elapsed time: 52.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 55.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 55.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 56.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 55.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 57.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 56.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 57.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.15
# Detected doublet rate = 21.2%
# Estimated detectable doublet fraction = 61.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 34.4%
# Elapsed time: 37.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.15
# Detected doublet rate = 21.2%
# Estimated detectable doublet fraction = 61.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 34.4%
# Elapsed time: 36.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.15
# Detected doublet rate = 21.2%
# Estimated detectable doublet fraction = 61.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 34.4%
# Elapsed time: 36.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.15
# Detected doublet rate = 21.2%
# Estimated detectable doublet fraction = 61.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 34.4%
# Elapsed time: 36.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 9.5%
# Elapsed time: 2.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 9.5%
# Elapsed time: 2.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 9.5%
# Elapsed time: 2.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.9%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 9.5%
# Elapsed time: 2.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.67
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 8.3%
# Elapsed time: 7.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.67
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 8.3%
# Elapsed time: 7.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.67
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 8.3%
# Elapsed time: 7.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.67
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 8.3%
# Elapsed time: 6.8 seconds

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 924995 × 36601
#     obs: 'doublet_scores', 'predicted_doublets', 'sample_id', 'barcode'
#     var: 'SYMBOL', 'ENSEMBL'

# %%
adata.obs
# Out:
#                                                          doublet_scores  \
# TAAGCCTAGGGACCTC-1_HCA_BN_F13109713_and_HCA_BN_...  0.09950522264980756
# CGCACAATCCAGGTTG-1_HCA_BN_F13109713_and_HCA_BN_...  0.20180995475113112
# CGCTTCTAGGATTGCT-1_HCA_BN_F13109713_and_HCA_BN_...  0.18670076726342708
# CTTTAGTTCCCAGTAG-1_HCA_BN_F13109713_and_HCA_BN_...  0.30946291560102296
# CTGACCAAGGCTGTGC-1_HCA_BN_F13109713_and_HCA_BN_...  0.26082130965593786
# ...                                                                 ...
# AGTTATGTCCTTGCGT-1_HCA_BN_F12482363_and_HCA_BN_...  0.05263157894736842
# CAGCCAATCGATAACC-1_HCA_BN_F12482363_and_HCA_BN_...  0.06005221932114881
# CCTAAGGTCCACAATA-1_HCA_BN_F12482363_and_HCA_BN_...  0.04608294930875575
# CGTGGTTCAAGTGTTT-1_HCA_BN_F12482363_and_HCA_BN_...  0.03187250996015936
# CATCCTCAGGCTTAAC-1_HCA_BN_F12482363_and_HCA_BN_...  0.06557377049180327
#
#                                                    predicted_doublets  \
# TAAGCCTAGGGACCTC-1_HCA_BN_F13109713_and_HCA_BN_...              False
# CGCACAATCCAGGTTG-1_HCA_BN_F13109713_and_HCA_BN_...              False
# CGCTTCTAGGATTGCT-1_HCA_BN_F13109713_and_HCA_BN_...              False
# CTTTAGTTCCCAGTAG-1_HCA_BN_F13109713_and_HCA_BN_...              False
# CTGACCAAGGCTGTGC-1_HCA_BN_F13109713_and_HCA_BN_...              False
# ...                                                               ...
# AGTTATGTCCTTGCGT-1_HCA_BN_F12482363_and_HCA_BN_...              False
# CAGCCAATCGATAACC-1_HCA_BN_F12482363_and_HCA_BN_...              False
# CCTAAGGTCCACAATA-1_HCA_BN_F12482363_and_HCA_BN_...              False
# CGTGGTTCAAGTGTTT-1_HCA_BN_F12482363_and_HCA_BN_...              False
# CATCCTCAGGCTTAAC-1_HCA_BN_F12482363_and_HCA_BN_...              False
#
#                                                                                 sample_id  \
# TAAGCCTAGGGACCTC-1_HCA_BN_F13109713_and_HCA_BN_...  HCA_BN_F13109713_and_HCA_BN_F13101383
# CGCACAATCCAGGTTG-1_HCA_BN_F13109713_and_HCA_BN_...  HCA_BN_F13109713_and_HCA_BN_F13101383
# CGCTTCTAGGATTGCT-1_HCA_BN_F13109713_and_HCA_BN_...  HCA_BN_F13109713_and_HCA_BN_F13101383
# CTTTAGTTCCCAGTAG-1_HCA_BN_F13109713_and_HCA_BN_...  HCA_BN_F13109713_and_HCA_BN_F13101383
# CTGACCAAGGCTGTGC-1_HCA_BN_F13109713_and_HCA_BN_...  HCA_BN_F13109713_and_HCA_BN_F13101383
# ...                                                                                   ...
# AGTTATGTCCTTGCGT-1_HCA_BN_F12482363_and_HCA_BN_...  HCA_BN_F12482363_and_HCA_BN_F12477275
# CAGCCAATCGATAACC-1_HCA_BN_F12482363_and_HCA_BN_...  HCA_BN_F12482363_and_HCA_BN_F12477275
# CCTAAGGTCCACAATA-1_HCA_BN_F12482363_and_HCA_BN_...  HCA_BN_F12482363_and_HCA_BN_F12477275
# CGTGGTTCAAGTGTTT-1_HCA_BN_F12482363_and_HCA_BN_...  HCA_BN_F12482363_and_HCA_BN_F12477275
# CATCCTCAGGCTTAAC-1_HCA_BN_F12482363_and_HCA_BN_...  HCA_BN_F12482363_and_HCA_BN_F12477275
#
#                                                                barcode
# TAAGCCTAGGGACCTC-1_HCA_BN_F13109713_and_HCA_BN_...  TAAGCCTAGGGACCTC-1
# CGCACAATCCAGGTTG-1_HCA_BN_F13109713_and_HCA_BN_...  CGCACAATCCAGGTTG-1
# CGCTTCTAGGATTGCT-1_HCA_BN_F13109713_and_HCA_BN_...  CGCTTCTAGGATTGCT-1
# CTTTAGTTCCCAGTAG-1_HCA_BN_F13109713_and_HCA_BN_...  CTTTAGTTCCCAGTAG-1
# CTGACCAAGGCTGTGC-1_HCA_BN_F13109713_and_HCA_BN_...  CTGACCAAGGCTGTGC-1
# ...                                                                ...
# AGTTATGTCCTTGCGT-1_HCA_BN_F12482363_and_HCA_BN_...  AGTTATGTCCTTGCGT-1
# CAGCCAATCGATAACC-1_HCA_BN_F12482363_and_HCA_BN_...  CAGCCAATCGATAACC-1
# CCTAAGGTCCACAATA-1_HCA_BN_F12482363_and_HCA_BN_...  CCTAAGGTCCACAATA-1
# CGTGGTTCAAGTGTTT-1_HCA_BN_F12482363_and_HCA_BN_...  CGTGGTTCAAGTGTTT-1
# CATCCTCAGGCTTAAC-1_HCA_BN_F12482363_and_HCA_BN_...  CATCCTCAGGCTTAAC-1
#
# [924995 rows x 4 columns]

# %%
adata.obs["sample_id"].value_counts()[:10]
# Out:
# sample_id
# HCA_BN_F12863835_and_HCA_BN_F12865000    34958
# HCA_BN_F13109713_and_HCA_BN_F13101383    32474
# HCA_BN_F13109710_and_HCA_BN_F13101380    22183
# HCA_BN_F13109711_and_HCA_BN_F13101381    21755
# HCA_BN_F12966457_and_HCA_BN_F12951833    21730
# HCA_BN_F13177437_and_HCA_BN_F13177210    21195
# HCA_BN_F12966460_and_HCA_BN_F12951836    20866
# HCA_BN_F12966455_and_HCA_BN_F12951831    20620
# HCA_BN_F12922487_and_HCA_BN_F12918725    20472
# HCA_BN_F12966459_and_HCA_BN_F12951835    20320
# Name: count, dtype: int64

# %%
adata.var.drop(columns=['ENSEMBL'], inplace=True)

# %%
meninges_sample= sc.read_10x_h5('HCA_BRA_F13774552_and_HCA_BRA_F13768422/HCA_BRA_F13774552_and_HCA_BRA_F13768422_filtered.h5')

# %%
scrub = scr.Scrublet(meninges_sample.X.copy())
doublet_scores, predicted_doublets = scrub.scrub_doublets()
meninges_sample.obs['doublet_scores'] = doublet_scores
meninges_sample.obs['predicted_doublets'] = predicted_doublets
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.17
# Detected doublet rate = 24.4%
# Estimated detectable doublet fraction = 65.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 37.2%
# Elapsed time: 26.6 seconds

# %%
meninges_sample.obs
# Out:
#                     doublet_scores  predicted_doublets
# CTGATCACAATATGGA-1        0.226994                True
# TGGCCATCATGCTCCC-1        0.242718                True
# CAATATGTCGGTCATG-1        0.234646                True
# TGGTTAATCGGTCAAT-1        0.212828                True
# TCGGTTTGTGACCTGG-1        0.200000                True
# ...                            ...                 ...
# CTTCTCAAGCTATTAG-1        0.012195               False
# TCGCGAGGTGCAACTA-1        0.081081               False
# GGTTCTTGTCGCGCAA-1        0.014573               False
# TTTGTCCCAGCCTGCA-1        0.086651               False
# CAAGGCTGTGAGCGAA-1        0.119847               False
#
# [13587 rows x 2 columns]

# %%
meninges_sample.var['ENSEMBL'] = meninges_sample.var.index
meninges_sample.var.rename(columns = {'gene_ids':'SYMBOL'}, inplace = True)
meninges_sample.var.index = meninges_sample.var['SYMBOL']
meninges_sample.var_names_make_unique()
meninges_sample.obs['sample_id'] = 'HCA_BRA_F13774552_and_HCA_BRA_F13768422'
meninges_sample.obs['barcode'] = meninges_sample.obs_names
meninges_sample.obs_names = meninges_sample.obs['barcode']+"_"+meninges_sample.obs['sample_id']

# %%
meninges_sample.var.drop(columns=['ENSEMBL'], inplace=True)

# %%
meninges_sample
# Out:
# AnnData object with n_obs × n_vars = 13587 × 36601
#     obs: 'doublet_scores', 'predicted_doublets', 'sample_id', 'barcode'
#     var: 'SYMBOL'

# %%
meninges_sample.obs
# Out:
#                                                     doublet_scores  \
# CTGATCACAATATGGA-1_HCA_BRA_F13774552_and_HCA_BR...        0.226994
# TGGCCATCATGCTCCC-1_HCA_BRA_F13774552_and_HCA_BR...        0.242718
# CAATATGTCGGTCATG-1_HCA_BRA_F13774552_and_HCA_BR...        0.234646
# TGGTTAATCGGTCAAT-1_HCA_BRA_F13774552_and_HCA_BR...        0.212828
# TCGGTTTGTGACCTGG-1_HCA_BRA_F13774552_and_HCA_BR...        0.200000
# ...                                                            ...
# CTTCTCAAGCTATTAG-1_HCA_BRA_F13774552_and_HCA_BR...        0.012195
# TCGCGAGGTGCAACTA-1_HCA_BRA_F13774552_and_HCA_BR...        0.081081
# GGTTCTTGTCGCGCAA-1_HCA_BRA_F13774552_and_HCA_BR...        0.014573
# TTTGTCCCAGCCTGCA-1_HCA_BRA_F13774552_and_HCA_BR...        0.086651
# CAAGGCTGTGAGCGAA-1_HCA_BRA_F13774552_and_HCA_BR...        0.119847
#
#                                                     predicted_doublets  \
# CTGATCACAATATGGA-1_HCA_BRA_F13774552_and_HCA_BR...                True
# TGGCCATCATGCTCCC-1_HCA_BRA_F13774552_and_HCA_BR...                True
# CAATATGTCGGTCATG-1_HCA_BRA_F13774552_and_HCA_BR...                True
# TGGTTAATCGGTCAAT-1_HCA_BRA_F13774552_and_HCA_BR...                True
# TCGGTTTGTGACCTGG-1_HCA_BRA_F13774552_and_HCA_BR...                True
# ...                                                                ...
# CTTCTCAAGCTATTAG-1_HCA_BRA_F13774552_and_HCA_BR...               False
# TCGCGAGGTGCAACTA-1_HCA_BRA_F13774552_and_HCA_BR...               False
# GGTTCTTGTCGCGCAA-1_HCA_BRA_F13774552_and_HCA_BR...               False
# TTTGTCCCAGCCTGCA-1_HCA_BRA_F13774552_and_HCA_BR...               False
# CAAGGCTGTGAGCGAA-1_HCA_BRA_F13774552_and_HCA_BR...               False
#
#                                                                                   sample_id  \
# CTGATCACAATATGGA-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
# TGGCCATCATGCTCCC-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
# CAATATGTCGGTCATG-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
# TGGTTAATCGGTCAAT-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
# TCGGTTTGTGACCTGG-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
# ...                                                                                     ...
# CTTCTCAAGCTATTAG-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
# TCGCGAGGTGCAACTA-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
# GGTTCTTGTCGCGCAA-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
# TTTGTCCCAGCCTGCA-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
# CAAGGCTGTGAGCGAA-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
#
#                                                                barcode
# CTGATCACAATATGGA-1_HCA_BRA_F13774552_and_HCA_BR...  CTGATCACAATATGGA-1
# TGGCCATCATGCTCCC-1_HCA_BRA_F13774552_and_HCA_BR...  TGGCCATCATGCTCCC-1
# CAATATGTCGGTCATG-1_HCA_BRA_F13774552_and_HCA_BR...  CAATATGTCGGTCATG-1
# TGGTTAATCGGTCAAT-1_HCA_BRA_F13774552_and_HCA_BR...  TGGTTAATCGGTCAAT-1
# TCGGTTTGTGACCTGG-1_HCA_BRA_F13774552_and_HCA_BR...  TCGGTTTGTGACCTGG-1
# ...                                                                ...
# CTTCTCAAGCTATTAG-1_HCA_BRA_F13774552_and_HCA_BR...  CTTCTCAAGCTATTAG-1
# TCGCGAGGTGCAACTA-1_HCA_BRA_F13774552_and_HCA_BR...  TCGCGAGGTGCAACTA-1
# GGTTCTTGTCGCGCAA-1_HCA_BRA_F13774552_and_HCA_BR...  GGTTCTTGTCGCGCAA-1
# TTTGTCCCAGCCTGCA-1_HCA_BRA_F13774552_and_HCA_BR...  TTTGTCCCAGCCTGCA-1
# CAAGGCTGTGAGCGAA-1_HCA_BRA_F13774552_and_HCA_BR...  CAAGGCTGTGAGCGAA-1
#
# [13587 rows x 4 columns]

# %%
meninges_skull=anndata.concat([adata,meninges_sample])

# %%
meninges_skull.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [MIR1302-2HG, FAM138A, OR4F5, AL627309.1, AL627309.3, AL627309.2, AL627309.5, AL627309.4, AP006222.2, AL732372.1, OR4F29, AC114498.1, OR4F16, AL669831.2, LINC01409, FAM87B, LINC01128, LINC00115, FAM41C, AL645608.6, AL645608.2, AL645608.4, LINC02593, SAMD11, NOC2L, KLHL17, PLEKHN1, PERM1, AL645608.7, HES4, ISG15, AL645608.1, AGRN, AL645608.5, AL645608.8, RNF223, C1orf159, AL390719.3, LINC01342, AL390719.2, TTLL10-AS1, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, C1QTNF12, AL162741.1, UBE2J2, LINC01786, SCNN1D, ACAP3, PUSL1, INTS11, AL139287.1, CPTP, TAS1R3, DVL1, MXRA8, AURKAIP1, CCNL2, MRPL20-AS1, MRPL20, AL391244.2, ANKRD65, AL391244.1, TMEM88B, LINC01770, VWA1, ATAD3C, ATAD3B, ATAD3A, TMEM240, SSU72, AL645728.1, FNDC10, AL691432.4, AL691432.2, MIB2, MMP23B, CDK11B, FO704657.1, SLC35E2B, CDK11A, SLC35E2A, NADK, GNB1, AL109917.1, CALML6, TMEM52, CFAP74, AL391845.2, GABRD, AL391845.1, PRKCZ, AL590822.2, PRKCZ-AS1, FAAP20, AL590822.1, SKI, ...]
#
# [36601 rows x 0 columns]

# %%
meninges_skull.obs["doublet_scores"]=meninges_skull.obs["doublet_scores"].astype(float)

# %%
meninges_skull.obs.dtypes
# Out:
# doublet_scores         float64
# predicted_doublets      object
# sample_id             category
# barcode               category
# dtype: object

# %%
meninges_skull.obs['predicted_doublets'] = meninges_skull.obs['predicted_doublets'].astype(str)

# %%
meninges_skull.obs.dtypes
# Out:
# doublet_scores         float64
# predicted_doublets    category
# sample_id             category
# barcode               category
# dtype: object

# %% [markdown]
# ## save object

# %%
meninges_skull.write_h5ad("/lustre/scratch126/cellgen/team298/sm54/Data_Integration/Integrated_Object/data/meninges_skull_cellbender_filtered_raw_counts_with_doublet_scores_20231019.h5ad")

# %%
meninges_skull.obs.dtypes
# Out:
# doublet_scores         float64
# predicted_doublets    category
# sample_id             category
# barcode               category
# dtype: object

# %% [markdown]
# # Spine

# %%
cd /lustre/scratch126/cellgen/team298/sm54/Data_Integration/Spine/data/cellranger_outputs_all_samples/
# Out:
# /lustre/scratch126/cellgen/team298/sm54/Data_Integration/Spine/data/cellranger_outputs_all_samples

# %% [markdown]
# # Metadata

# %%
metadata= pd.read_csv("/home/jovyan/mount/gdrive/Spine/metadata_spine_DRteam.csv")

# %%
metadata
# Out:
#     PCW    region subregion dissociation      batch  \
# 0   7.0    lumbar  cervical   no_trypsin  HDBR15918
# 1   7.0  thoracic  thoracic   no_trypsin  HDBR15918
# 2   7.0  cervical    lumbar   no_trypsin  HDBR15918
# 3   5.0  cervical  cervical   no_trypsin  HDBR15868
# 4   5.0  cervical  cervical      trypsin  HDBR15868
# ..  ...       ...       ...          ...        ...
# 63  NaN       NaN       NaN          NaN        NaN
# 64  NaN       NaN       NaN          NaN        NaN
# 65  NaN       NaN       NaN          NaN        NaN
# 66  NaN       NaN       NaN          NaN        NaN
# 67  NaN       NaN       NaN          NaN        NaN
#
#                                            irods_path
# 0   cellranger600_count_40813_SB_200532_10841321_G...
# 1   cellranger600_count_40813_SB_200532_10841322_G...
# 2   cellranger600_count_40813_SB_200532_10841323_G...
# 3   cellranger600_count_41025_SB_200532_10621989_G...
# 4   cellranger600_count_41025_SB_200532_10621992_G...
# ..                                                ...
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
#
# [68 rows x 6 columns]

# %%
metadata=metadata.dropna(how='all')

# %%
metadata
# Out:
#      PCW     region subregion dissociation      batch  \
# 0    7.0     lumbar  cervical   no_trypsin  HDBR15918
# 1    7.0   thoracic  thoracic   no_trypsin  HDBR15918
# 2    7.0   cervical    lumbar   no_trypsin  HDBR15918
# 3    5.0   cervical  cervical   no_trypsin  HDBR15868
# 4    5.0   cervical  cervical      trypsin  HDBR15868
# ..   ...        ...       ...          ...        ...
# 57  17.0   cervical       NaN      trypsin  HDBR15948
# 58  17.0  thoracic        NaN      trypsin  HDBR15948
# 59  17.0   thoracic       NaN      trypsin  HDBR15948
# 60  17.0     lumbar       NaN      trypsin  HDBR15948
# 61  17.0     sacral       NaN      trypsin  HDBR15948
#
#                                            irods_path
# 0   cellranger600_count_40813_SB_200532_10841321_G...
# 1   cellranger600_count_40813_SB_200532_10841322_G...
# 2   cellranger600_count_40813_SB_200532_10841323_G...
# 3   cellranger600_count_41025_SB_200532_10621989_G...
# 4   cellranger600_count_41025_SB_200532_10621992_G...
# ..                                                ...
# 57  cellranger600_count_41865_SB_200532_11018320_G...
# 58  cellranger600_count_41865_SB_200532_11018321_G...
# 59  cellranger600_count_41865_SB_200532_11018322_G...
# 60  cellranger600_count_41865_SB_200532_11018323_G...
# 61  cellranger600_count_41865_SB_200532_11018324_G...
#
# [62 rows x 6 columns]

# %%
metadata["irods_path"]= metadata["irods_path"].astype(str)
# Out:
# /tmp/ipykernel_276/933390425.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata["irods_path"]= metadata["irods_path"].astype(str)

# %%
metadata
# Out:
#      PCW     region subregion dissociation      batch  \
# 0    7.0     lumbar  cervical   no_trypsin  HDBR15918
# 1    7.0   thoracic  thoracic   no_trypsin  HDBR15918
# 2    7.0   cervical    lumbar   no_trypsin  HDBR15918
# 3    5.0   cervical  cervical   no_trypsin  HDBR15868
# 4    5.0   cervical  cervical      trypsin  HDBR15868
# ..   ...        ...       ...          ...        ...
# 57  17.0   cervical       NaN      trypsin  HDBR15948
# 58  17.0  thoracic        NaN      trypsin  HDBR15948
# 59  17.0   thoracic       NaN      trypsin  HDBR15948
# 60  17.0     lumbar       NaN      trypsin  HDBR15948
# 61  17.0     sacral       NaN      trypsin  HDBR15948
#
#                                            irods_path
# 0   cellranger600_count_40813_SB_200532_10841321_G...
# 1   cellranger600_count_40813_SB_200532_10841322_G...
# 2   cellranger600_count_40813_SB_200532_10841323_G...
# 3   cellranger600_count_41025_SB_200532_10621989_G...
# 4   cellranger600_count_41025_SB_200532_10621992_G...
# ..                                                ...
# 57  cellranger600_count_41865_SB_200532_11018320_G...
# 58  cellranger600_count_41865_SB_200532_11018321_G...
# 59  cellranger600_count_41865_SB_200532_11018322_G...
# 60  cellranger600_count_41865_SB_200532_11018323_G...
# 61  cellranger600_count_41865_SB_200532_11018324_G...
#
# [62 rows x 6 columns]

# %%
arr = os.listdir()

sample_list= metadata["irods_path"].tolist()

sample_list = [x for x in sample_list if str(x) != 'nan']


filter_data = [x for x in arr if
              any(y in x for y in sample_list)]

# %%
filter_data
# Out:
# ['cellranger600_count_39102_SB_200532_10297929_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254458_GRCh38-2020-A',
#  'cellranger600_count_41025_SB_200532_10621989_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297927_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254464_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863985_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254461_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863987_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018320_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841321_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018319_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297930_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254463_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254465_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863988_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863995_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841317_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254460_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018313_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841322_GRCh38-2020-A',
#  'cellranger600_count_41025_SB_200532_10621990_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018316_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032967_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863992_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841319_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254462_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297931_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297933_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297926_GRCh38-2020-A',
#  'cellranger600_count_41025_SB_200532_10621992_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254466_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018322_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032964_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032966_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032969_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018324_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863994_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018314_GRCh38-2020-A',
#  'cellranger600_count_41025_SB_200532_10621991_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863993_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032965_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297924_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018321_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863986_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297928_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254459_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297923_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841320_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018315_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297932_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841323_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297922_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297925_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863991_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018318_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863989_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018317_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841318_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018323_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032968_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841316_GRCh38-2020-A']

# %%
len(filter_data)
# Out:
# 61

# %%
gc.collect()
# Out:
# 2302

# %%
import scrublet as scr

# %%
def read_10x_output_spine(smp_list, type = 'filtered'):
    import os
    
    #Writing output from separate samples, processed using CellRanger, into a dictionary of Scanpy objects:
    ad = {}

    #Generate AnnData for each sample
    for sample_name in smp_list:
        path = sample_name
        for i in os.listdir(path):
            if type in i and 'h5' in i:
                file = i
        ad[sample_name] = sc.read_10x_h5(sample_name +'/'+file)
        scrub = scr.Scrublet(ad[sample_name].X.copy())
        doublet_scores, predicted_doublets = scrub.scrub_doublets()
        ad[sample_name].obs['doublet_scores'] = doublet_scores
        ad[sample_name].obs['predicted_doublets'] = predicted_doublets
        ad[sample_name].var['SYMBOL'] = ad[sample_name].var.index
        #ad[sample_name].var.drop(columns=['gene_ids',"feature_types","genome"], inplace=True)
        ad[sample_name].var_names_make_unique() 
        ad[sample_name].obs['sample_id'] = sample_name
        ad[sample_name].obs['barcode'] = ad[sample_name].obs_names

    #Merge AnnData objects from all the samples together    
    from scipy.sparse import vstack
    stack = vstack([ad[x].X for x in smp_list]) # stack data
    adata = sc.AnnData(stack, var = ad[smp_list[0]].var)
    adata.obs = pd.concat([ad[x].obs for x in smp_list], axis = 0)

    for c in adata.obs.columns:
        adata.obs[c] = adata.obs[c].astype('str')
    adata.obs =  adata.obs.copy()

    return adata, ad

# %%
warnings.filterwarnings('ignore')

spine, ad_list = read_10x_output_spine(
    smp_list=filter_data,
    
    type='filtered'
)
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.59
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 2.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 9.0%
# Elapsed time: 3.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.31
# Detected doublet rate = 3.1%
# Estimated detectable doublet fraction = 26.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 11.7%
# Elapsed time: 13.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.60
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 13.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.65
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 4.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 26.7%
# Elapsed time: 12.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 2.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 15.4%
# Elapsed time: 2.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.67
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.8%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 3.5%
# Elapsed time: 5.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 3.9%
# Elapsed time: 2.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.51
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 35.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.70
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 26.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.16
# Detected doublet rate = 25.3%
# Estimated detectable doublet fraction = 58.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 43.1%
# Elapsed time: 34.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.74
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 26.1%
# Elapsed time: 12.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Warning: failed to automatically identify doublet score threshold. Run `call_doublets` with user-specified threshold.
# Elapsed time: 55.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.63
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 15.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.60
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 2.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 8.6%
# Elapsed time: 2.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 6.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 9.4%
# Elapsed time: 1.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 9.9%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 4.3%
# Elapsed time: 8.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 1.4%
# Estimated detectable doublet fraction = 14.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 9.8%
# Elapsed time: 6.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.46
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 17.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.76
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 16.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.66
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 20.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.20
# Detected doublet rate = 14.7%
# Estimated detectable doublet fraction = 45.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 32.1%
# Elapsed time: 27.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.34
# Detected doublet rate = 2.3%
# Estimated detectable doublet fraction = 17.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 12.9%
# Elapsed time: 19.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.55
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 2.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 10.3%
# Elapsed time: 1.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.44
# Detected doublet rate = 2.2%
# Estimated detectable doublet fraction = 19.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 11.0%
# Elapsed time: 1.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 6.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 7.8%
# Elapsed time: 2.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 1.5%
# Estimated detectable doublet fraction = 18.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 8.2%
# Elapsed time: 10.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.67
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 12.8%
# Elapsed time: 5.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.41
# Detected doublet rate = 0.9%
# Estimated detectable doublet fraction = 12.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 7.4%
# Elapsed time: 12.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 3.8%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 5.5%
# Elapsed time: 7.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.26
# Detected doublet rate = 5.6%
# Estimated detectable doublet fraction = 27.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 20.3%
# Elapsed time: 31.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 50.0%
# Elapsed time: 33.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.67
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 19.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.62
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 100.0%
# Elapsed time: 20.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.58
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 7.8%
# Elapsed time: 20.0 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.20
# Detected doublet rate = 14.8%
# Estimated detectable doublet fraction = 46.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.8%
# Elapsed time: 54.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 4.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 13.0%
# Elapsed time: 1.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 21.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.67
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 12.9%
# Elapsed time: 19.8 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.6%
# Estimated detectable doublet fraction = 4.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 13.5%
# Elapsed time: 2.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.64
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 66.7%
# Elapsed time: 15.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.77
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 16.7%
# Elapsed time: 12.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.87
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 53.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 2.8%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 11.8%
# Elapsed time: 2.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.59
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 6.7%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 6.0%
# Elapsed time: 6.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 2.3%
# Estimated detectable doublet fraction = 22.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 10.2%
# Elapsed time: 8.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.35
# Detected doublet rate = 2.0%
# Estimated detectable doublet fraction = 22.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 9.1%
# Elapsed time: 9.6 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.49
# Detected doublet rate = 0.4%
# Estimated detectable doublet fraction = 8.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 4.7%
# Elapsed time: 3.3 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.16
# Detected doublet rate = 22.5%
# Estimated detectable doublet fraction = 61.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 36.5%
# Elapsed time: 42.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.47
# Detected doublet rate = 0.8%
# Estimated detectable doublet fraction = 2.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 36.4%
# Elapsed time: 2.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.73
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 14.3%
# Elapsed time: 20.5 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 1.9%
# Estimated detectable doublet fraction = 22.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 8.5%
# Elapsed time: 10.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 1.3%
# Estimated detectable doublet fraction = 17.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 7.5%
# Elapsed time: 10.1 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.1%
# Estimated detectable doublet fraction = 1.3%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 10.8%
# Elapsed time: 2.9 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.23
# Detected doublet rate = 12.0%
# Estimated detectable doublet fraction = 38.8%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 31.0%
# Elapsed time: 57.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.53
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 1.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 16.7%
# Elapsed time: 1.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.18
# Detected doublet rate = 17.3%
# Estimated detectable doublet fraction = 52.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 32.9%
# Elapsed time: 32.2 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.68
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 1.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 2.5%
# Elapsed time: 9.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.52
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 20.7 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.67
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 12.4 seconds
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.38
# Detected doublet rate = 1.7%
# Estimated detectable doublet fraction = 34.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 5.0%
# Elapsed time: 2.8 seconds

# %%
spine
# Out:
# AnnData object with n_obs × n_vars = 547321 × 36601
#     obs: 'doublet_scores', 'predicted_doublets', 'sample_id', 'barcode'
#     var: 'gene_ids', 'feature_types', 'genome', 'SYMBOL'

# %%
spine.obs
# Out:
#                           doublet_scores predicted_doublets  \
# AAACCCAGTATTGAGA-1  0.057432432432432436              False
# AAACGAAAGACCATAA-1               0.15625              False
# AAACGAACACGCTGCA-1    0.0979498861047836              False
# AAACGAAGTATACCCA-1    0.0816326530612245              False
# AAACGAATCACGACTA-1   0.14540059347181006              False
# ...                                  ...                ...
# TTTGGTTCACTACACA-1   0.10358565737051792              False
# TTTGGTTTCAGGGTAG-1    0.0488771466314399              False
# TTTGGTTTCCGCAACG-1   0.08006814310051105              False
# TTTGTTGGTAACGTTC-1   0.05135135135135135              False
# TTTGTTGGTGTTCGTA-1   0.09826589595375722              False
#
#                                                             sample_id  \
# AAACCCAGTATTGAGA-1  cellranger600_count_39102_SB_200532_10297929_G...
# AAACGAAAGACCATAA-1  cellranger600_count_39102_SB_200532_10297929_G...
# AAACGAACACGCTGCA-1  cellranger600_count_39102_SB_200532_10297929_G...
# AAACGAAGTATACCCA-1  cellranger600_count_39102_SB_200532_10297929_G...
# AAACGAATCACGACTA-1  cellranger600_count_39102_SB_200532_10297929_G...
# ...                                                               ...
# TTTGGTTCACTACACA-1  cellranger600_count_40813_SB_200532_10841316_G...
# TTTGGTTTCAGGGTAG-1  cellranger600_count_40813_SB_200532_10841316_G...
# TTTGGTTTCCGCAACG-1  cellranger600_count_40813_SB_200532_10841316_G...
# TTTGTTGGTAACGTTC-1  cellranger600_count_40813_SB_200532_10841316_G...
# TTTGTTGGTGTTCGTA-1  cellranger600_count_40813_SB_200532_10841316_G...
#
#                                barcode
# AAACCCAGTATTGAGA-1  AAACCCAGTATTGAGA-1
# AAACGAAAGACCATAA-1  AAACGAAAGACCATAA-1
# AAACGAACACGCTGCA-1  AAACGAACACGCTGCA-1
# AAACGAAGTATACCCA-1  AAACGAAGTATACCCA-1
# AAACGAATCACGACTA-1  AAACGAATCACGACTA-1
# ...                                ...
# TTTGGTTCACTACACA-1  TTTGGTTCACTACACA-1
# TTTGGTTTCAGGGTAG-1  TTTGGTTTCAGGGTAG-1
# TTTGGTTTCCGCAACG-1  TTTGGTTTCCGCAACG-1
# TTTGTTGGTAACGTTC-1  TTTGTTGGTAACGTTC-1
# TTTGTTGGTGTTCGTA-1  TTTGTTGGTGTTCGTA-1
#
# [547321 rows x 4 columns]

# %%
spine.var.drop(columns=['gene_ids',"feature_types","genome"], inplace=True)

# %%
spine.var
# Out:
#                   SYMBOL
# MIR1302-2HG  MIR1302-2HG
# FAM138A          FAM138A
# OR4F5              OR4F5
# AL627309.1    AL627309.1
# AL627309.3    AL627309.3
# ...                  ...
# AC141272.1    AC141272.1
# AC023491.2    AC023491.2
# AC007325.1    AC007325.1
# AC007325.4    AC007325.4
# AC007325.2    AC007325.2
#
# [36601 rows x 1 columns]

# %% [markdown]
# ## save object

# %%
spine.write_h5ad("/lustre/scratch126/cellgen/team298/sm54/Data_Integration/Integrated_Object/data/spine_no_cellbender_filtered_raw_counts_with_doublet_scores_20231018.h5ad")

# %% [markdown]
# # Combined anndata

# %%
meninges_skull= sc.read_h5ad("/lustre/scratch126/cellgen/team298/sm54/Data_Integration/Integrated_Object/data/meninges_skull_cellbender_filtered_raw_counts_with_doublet_scores_20231019.h5ad")

# %%
meninges_skull.obs
# Out:
#                                                     doublet_scores  \
# TAAGCCTAGGGACCTC-1_HCA_BN_F13109713_and_HCA_BN_...        0.099505
# CGCACAATCCAGGTTG-1_HCA_BN_F13109713_and_HCA_BN_...        0.201810
# CGCTTCTAGGATTGCT-1_HCA_BN_F13109713_and_HCA_BN_...        0.186701
# CTTTAGTTCCCAGTAG-1_HCA_BN_F13109713_and_HCA_BN_...        0.309463
# CTGACCAAGGCTGTGC-1_HCA_BN_F13109713_and_HCA_BN_...        0.260821
# ...                                                            ...
# CTTCTCAAGCTATTAG-1_HCA_BRA_F13774552_and_HCA_BR...        0.012195
# TCGCGAGGTGCAACTA-1_HCA_BRA_F13774552_and_HCA_BR...        0.081081
# GGTTCTTGTCGCGCAA-1_HCA_BRA_F13774552_and_HCA_BR...        0.014573
# TTTGTCCCAGCCTGCA-1_HCA_BRA_F13774552_and_HCA_BR...        0.086651
# CAAGGCTGTGAGCGAA-1_HCA_BRA_F13774552_and_HCA_BR...        0.119847
#
#                                                    predicted_doublets  \
# TAAGCCTAGGGACCTC-1_HCA_BN_F13109713_and_HCA_BN_...              False
# CGCACAATCCAGGTTG-1_HCA_BN_F13109713_and_HCA_BN_...              False
# CGCTTCTAGGATTGCT-1_HCA_BN_F13109713_and_HCA_BN_...              False
# CTTTAGTTCCCAGTAG-1_HCA_BN_F13109713_and_HCA_BN_...              False
# CTGACCAAGGCTGTGC-1_HCA_BN_F13109713_and_HCA_BN_...              False
# ...                                                               ...
# CTTCTCAAGCTATTAG-1_HCA_BRA_F13774552_and_HCA_BR...              False
# TCGCGAGGTGCAACTA-1_HCA_BRA_F13774552_and_HCA_BR...              False
# GGTTCTTGTCGCGCAA-1_HCA_BRA_F13774552_and_HCA_BR...              False
# TTTGTCCCAGCCTGCA-1_HCA_BRA_F13774552_and_HCA_BR...              False
# CAAGGCTGTGAGCGAA-1_HCA_BRA_F13774552_and_HCA_BR...              False
#
#                                                                                   sample_id  \
# TAAGCCTAGGGACCTC-1_HCA_BN_F13109713_and_HCA_BN_...    HCA_BN_F13109713_and_HCA_BN_F13101383
# CGCACAATCCAGGTTG-1_HCA_BN_F13109713_and_HCA_BN_...    HCA_BN_F13109713_and_HCA_BN_F13101383
# CGCTTCTAGGATTGCT-1_HCA_BN_F13109713_and_HCA_BN_...    HCA_BN_F13109713_and_HCA_BN_F13101383
# CTTTAGTTCCCAGTAG-1_HCA_BN_F13109713_and_HCA_BN_...    HCA_BN_F13109713_and_HCA_BN_F13101383
# CTGACCAAGGCTGTGC-1_HCA_BN_F13109713_and_HCA_BN_...    HCA_BN_F13109713_and_HCA_BN_F13101383
# ...                                                                                     ...
# CTTCTCAAGCTATTAG-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
# TCGCGAGGTGCAACTA-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
# GGTTCTTGTCGCGCAA-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
# TTTGTCCCAGCCTGCA-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
# CAAGGCTGTGAGCGAA-1_HCA_BRA_F13774552_and_HCA_BR...  HCA_BRA_F13774552_and_HCA_BRA_F13768422
#
#                                                                barcode
# TAAGCCTAGGGACCTC-1_HCA_BN_F13109713_and_HCA_BN_...  TAAGCCTAGGGACCTC-1
# CGCACAATCCAGGTTG-1_HCA_BN_F13109713_and_HCA_BN_...  CGCACAATCCAGGTTG-1
# CGCTTCTAGGATTGCT-1_HCA_BN_F13109713_and_HCA_BN_...  CGCTTCTAGGATTGCT-1
# CTTTAGTTCCCAGTAG-1_HCA_BN_F13109713_and_HCA_BN_...  CTTTAGTTCCCAGTAG-1
# CTGACCAAGGCTGTGC-1_HCA_BN_F13109713_and_HCA_BN_...  CTGACCAAGGCTGTGC-1
# ...                                                                ...
# CTTCTCAAGCTATTAG-1_HCA_BRA_F13774552_and_HCA_BR...  CTTCTCAAGCTATTAG-1
# TCGCGAGGTGCAACTA-1_HCA_BRA_F13774552_and_HCA_BR...  TCGCGAGGTGCAACTA-1
# GGTTCTTGTCGCGCAA-1_HCA_BRA_F13774552_and_HCA_BR...  GGTTCTTGTCGCGCAA-1
# TTTGTCCCAGCCTGCA-1_HCA_BRA_F13774552_and_HCA_BR...  TTTGTCCCAGCCTGCA-1
# CAAGGCTGTGAGCGAA-1_HCA_BRA_F13774552_and_HCA_BR...  CAAGGCTGTGAGCGAA-1
#
# [938582 rows x 4 columns]

# %%
meninges_skull.var["SYMBOL"]= meninges_skull.var.index

# %%
meninges_skull
# Out:
# AnnData object with n_obs × n_vars = 938582 × 36601
#     obs: 'doublet_scores', 'predicted_doublets', 'sample_id', 'barcode'
#     var: 'SYMBOL'

# %%
spine= sc.read_h5ad("/lustre/scratch126/cellgen/team298/sm54/Data_Integration/Integrated_Object/data/spine_no_cellbender_filtered_raw_counts_with_doublet_scores_20231018.h5ad")
# Out:
# /home/jovyan/my-conda-envs/cns_haem/lib/python3.10/site-packages/anndata/_core/anndata.py:1898: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
spine.obs
# Out:
#                           doublet_scores predicted_doublets  \
# AAACCCAGTATTGAGA-1  0.057432432432432436              False
# AAACGAAAGACCATAA-1               0.15625              False
# AAACGAACACGCTGCA-1    0.0979498861047836              False
# AAACGAAGTATACCCA-1    0.0816326530612245              False
# AAACGAATCACGACTA-1   0.14540059347181006              False
# ...                                  ...                ...
# TTTGGTTCACTACACA-1   0.10358565737051792              False
# TTTGGTTTCAGGGTAG-1    0.0488771466314399              False
# TTTGGTTTCCGCAACG-1   0.08006814310051105              False
# TTTGTTGGTAACGTTC-1   0.05135135135135135              False
# TTTGTTGGTGTTCGTA-1   0.09826589595375722              False
#
#                                                             sample_id  \
# AAACCCAGTATTGAGA-1  cellranger600_count_39102_SB_200532_10297929_G...
# AAACGAAAGACCATAA-1  cellranger600_count_39102_SB_200532_10297929_G...
# AAACGAACACGCTGCA-1  cellranger600_count_39102_SB_200532_10297929_G...
# AAACGAAGTATACCCA-1  cellranger600_count_39102_SB_200532_10297929_G...
# AAACGAATCACGACTA-1  cellranger600_count_39102_SB_200532_10297929_G...
# ...                                                               ...
# TTTGGTTCACTACACA-1  cellranger600_count_40813_SB_200532_10841316_G...
# TTTGGTTTCAGGGTAG-1  cellranger600_count_40813_SB_200532_10841316_G...
# TTTGGTTTCCGCAACG-1  cellranger600_count_40813_SB_200532_10841316_G...
# TTTGTTGGTAACGTTC-1  cellranger600_count_40813_SB_200532_10841316_G...
# TTTGTTGGTGTTCGTA-1  cellranger600_count_40813_SB_200532_10841316_G...
#
#                                barcode
# AAACCCAGTATTGAGA-1  AAACCCAGTATTGAGA-1
# AAACGAAAGACCATAA-1  AAACGAAAGACCATAA-1
# AAACGAACACGCTGCA-1  AAACGAACACGCTGCA-1
# AAACGAAGTATACCCA-1  AAACGAAGTATACCCA-1
# AAACGAATCACGACTA-1  AAACGAATCACGACTA-1
# ...                                ...
# TTTGGTTCACTACACA-1  TTTGGTTCACTACACA-1
# TTTGGTTTCAGGGTAG-1  TTTGGTTTCAGGGTAG-1
# TTTGGTTTCCGCAACG-1  TTTGGTTTCCGCAACG-1
# TTTGTTGGTAACGTTC-1  TTTGTTGGTAACGTTC-1
# TTTGTTGGTGTTCGTA-1  TTTGTTGGTGTTCGTA-1
#
# [547321 rows x 4 columns]

# %%
spine.obs.dtypes
# Out:
# doublet_scores        category
# predicted_doublets    category
# sample_id             category
# barcode               category
# dtype: object

# %%
spine.obs["doublet_scores"]=spine.obs["doublet_scores"].astype(float)

# %%
spine.obs.dtypes
# Out:
# doublet_scores         float64
# predicted_doublets    category
# sample_id             category
# barcode               category
# dtype: object

# %%
doublet_cutoff = 0.2  # Adjust this value as needed

# Filter out cells with a doublet score below the cutoff
spine[spine.obs['doublet_scores'] >= doublet_cutoff].copy()

# The 'filtered_adata' now contains cells with doublet scores above or equal to the cutoff
# Out:
# /home/jovyan/my-conda-envs/cns_haem/lib/python3.10/site-packages/anndata/_core/anndata.py:1898: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 59791 × 36601
#     obs: 'doublet_scores', 'predicted_doublets', 'sample_id', 'barcode'
#     var: 'SYMBOL'

# %%
combined_object= anndata.concat([meninges_skull,spine])
# Out:
# /home/jovyan/my-conda-envs/cns_haem/lib/python3.10/site-packages/anndata/_core/anndata.py:1898: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
combined_object.obs
# Out:
#                                                     doublet_scores  \
# TAAGCCTAGGGACCTC-1_HCA_BN_F13109713_and_HCA_BN_...        0.099505
# CGCACAATCCAGGTTG-1_HCA_BN_F13109713_and_HCA_BN_...        0.201810
# CGCTTCTAGGATTGCT-1_HCA_BN_F13109713_and_HCA_BN_...        0.186701
# CTTTAGTTCCCAGTAG-1_HCA_BN_F13109713_and_HCA_BN_...        0.309463
# CTGACCAAGGCTGTGC-1_HCA_BN_F13109713_and_HCA_BN_...        0.260821
# ...                                                            ...
# TTTGGTTCACTACACA-1                                        0.103586
# TTTGGTTTCAGGGTAG-1                                        0.048877
# TTTGGTTTCCGCAACG-1                                        0.080068
# TTTGTTGGTAACGTTC-1                                        0.051351
# TTTGTTGGTGTTCGTA-1                                        0.098266
#
#                                                    predicted_doublets  \
# TAAGCCTAGGGACCTC-1_HCA_BN_F13109713_and_HCA_BN_...              False
# CGCACAATCCAGGTTG-1_HCA_BN_F13109713_and_HCA_BN_...              False
# CGCTTCTAGGATTGCT-1_HCA_BN_F13109713_and_HCA_BN_...              False
# CTTTAGTTCCCAGTAG-1_HCA_BN_F13109713_and_HCA_BN_...              False
# CTGACCAAGGCTGTGC-1_HCA_BN_F13109713_and_HCA_BN_...              False
# ...                                                               ...
# TTTGGTTCACTACACA-1                                              False
# TTTGGTTTCAGGGTAG-1                                              False
# TTTGGTTTCCGCAACG-1                                              False
# TTTGTTGGTAACGTTC-1                                              False
# TTTGTTGGTGTTCGTA-1                                              False
#
#                                                                                             sample_id  \
# TAAGCCTAGGGACCTC-1_HCA_BN_F13109713_and_HCA_BN_...              HCA_BN_F13109713_and_HCA_BN_F13101383
# CGCACAATCCAGGTTG-1_HCA_BN_F13109713_and_HCA_BN_...              HCA_BN_F13109713_and_HCA_BN_F13101383
# CGCTTCTAGGATTGCT-1_HCA_BN_F13109713_and_HCA_BN_...              HCA_BN_F13109713_and_HCA_BN_F13101383
# CTTTAGTTCCCAGTAG-1_HCA_BN_F13109713_and_HCA_BN_...              HCA_BN_F13109713_and_HCA_BN_F13101383
# CTGACCAAGGCTGTGC-1_HCA_BN_F13109713_and_HCA_BN_...              HCA_BN_F13109713_and_HCA_BN_F13101383
# ...                                                                                               ...
# TTTGGTTCACTACACA-1                                  cellranger600_count_40813_SB_200532_10841316_G...
# TTTGGTTTCAGGGTAG-1                                  cellranger600_count_40813_SB_200532_10841316_G...
# TTTGGTTTCCGCAACG-1                                  cellranger600_count_40813_SB_200532_10841316_G...
# TTTGTTGGTAACGTTC-1                                  cellranger600_count_40813_SB_200532_10841316_G...
# TTTGTTGGTGTTCGTA-1                                  cellranger600_count_40813_SB_200532_10841316_G...
#
#                                                                barcode
# TAAGCCTAGGGACCTC-1_HCA_BN_F13109713_and_HCA_BN_...  TAAGCCTAGGGACCTC-1
# CGCACAATCCAGGTTG-1_HCA_BN_F13109713_and_HCA_BN_...  CGCACAATCCAGGTTG-1
# CGCTTCTAGGATTGCT-1_HCA_BN_F13109713_and_HCA_BN_...  CGCTTCTAGGATTGCT-1
# CTTTAGTTCCCAGTAG-1_HCA_BN_F13109713_and_HCA_BN_...  CTTTAGTTCCCAGTAG-1
# CTGACCAAGGCTGTGC-1_HCA_BN_F13109713_and_HCA_BN_...  CTGACCAAGGCTGTGC-1
# ...                                                                ...
# TTTGGTTCACTACACA-1                                  TTTGGTTCACTACACA-1
# TTTGGTTTCAGGGTAG-1                                  TTTGGTTTCAGGGTAG-1
# TTTGGTTTCCGCAACG-1                                  TTTGGTTTCCGCAACG-1
# TTTGTTGGTAACGTTC-1                                  TTTGTTGGTAACGTTC-1
# TTTGTTGGTGTTCGTA-1                                  TTTGTTGGTGTTCGTA-1
#
# [1485903 rows x 4 columns]

# %%
combined_object
# Out:
# AnnData object with n_obs × n_vars = 1485903 × 36601
#     obs: 'sample_id', 'barcode'

# %%
del spine

# %%
del meninges_skull

# %%
gc.collect()
# Out:
# 517

# %%
combined_object.write_h5ad("/lustre/scratch126/cellgen/team298/sm54/Data_Integration/Integrated_Object/data/combined_spine_skull_meninges_raw_counts_with_doublet_scores_20231019.h5ad")

# %%
combined_object
# Out:
# AnnData object with n_obs × n_vars = 1485903 × 36601
#     obs: 'doublet_scores', 'predicted_doublets', 'sample_id', 'barcode'
