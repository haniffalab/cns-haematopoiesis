# %%
import sys

import scanpy as sc
import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib as mpl
import scipy

import scvi
import hashlib

from matplotlib import rcParams
rcParams['pdf.fonttype'] = 42 # enables correct plotting of text
import seaborn as sns

# %%
pwd

# %%
# Code provided by Vitalii

def read_10x_output(smp_list, metadata=None, type = 'raw'):
    import os
    
    #Writing output from separate samples, processed using CellRanger, into a dictionary of Scanpy objects:
    ad = {}

    #Generate AnnData for each sample
    for sample_name in smp_list:
        path = sample_name
        for i in os.listdir(path):
            if type in i and 'h5' in i:
                file = i
        ad[sample_name] = sc.read_10x_h5(sample_name +'/'+file)
        ad[sample_name].var.rename(columns = {'gene_ids':'ENSEMBL'}, inplace = True)
        ad[sample_name].var['SYMBOL'] = ad[sample_name].var.index
        ad[sample_name].var.index = ad[sample_name].var['ENSEMBL']
        ad[sample_name].var.drop(columns=['ENSEMBL'], inplace=True)
        #ad[sample_name].var_names_make_unique() 
        
        
        sc.pp.calculate_qc_metrics(ad[sample_name], inplace=True)
        #ad[sample_name] = ad[sample_name][ad[sample_name].obs['total_counts'] > umi_filter, :]
        ad[sample_name].var['mt'] = [gene.startswith('mt-') 
                                     for gene in ad[sample_name].var['SYMBOL']]
        ad[sample_name].obs['mt_frac'] = (ad[sample_name][:, 
               ad[sample_name].var['mt'].tolist()].X.sum(1).A.squeeze() 
                                          / ad[sample_name].obs['total_counts'])
        
        ad[sample_name].obs['sample_id'] = sample_name
        ad[sample_name].obs['barcode'] = ad[sample_name].obs_names
        #ad[sample_name].obs_names = ad[sample_name].obs['barcode']+"_"+ad[sample_name].obs['sample_id']

    #Merge AnnData objects from all the samples together    
    from scipy.sparse import vstack
    stack = vstack([ad[x].X for x in smp_list]) # stack data
    adata = sc.AnnData(stack, var = ad[smp_list[0]].var)
    adata.obs = pd.concat([ad[x].obs for x in smp_list], axis = 0)

    if metadata is not None:
        #Add cleaned metadata to the Anndata.obs table
        # obs_merged = pd.merge(left = adata.obs, right = metadata, 
        #                      how = "left", left_on="sample", right_on="sample")
        # obs_merged.index = obs_merged['sample']+"_"+obs_merged['barcode']
        # print(obs_merged.index.equals(adata.obs.index))
        # adata.obs = obs_merged
        adata.obs[metadata.columns] = metadata.reindex(index=adata.obs['sample_id']).values
    for c in adata.obs.columns:
        adata.obs[c] = adata.obs[c].astype('str')
    adata.obs =  adata.obs.copy()

    return adata, ad

# %%
cd /lustre/scratch126/cellgen/team205/jl29/samsidfetal/samsidfetal
# Out:
# /lustre/scratch126/cellgen/team205/jl29/samsidfetal/samsidfetal

# %%
sample_list= pd.read_csv("/home/jovyan/mount/gdrive/Spine/metadata_spine_DRteam.csv")

# %%
sample_list=list(sample_list['irods_path'])

# %%
sample_list
# Out:
# ['cellranger600_count_40813_SB_200532_10841321_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841322_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841323_GRCh38-2020-A',
#  'cellranger600_count_41025_SB_200532_10621989_GRCh38-2020-A',
#  'cellranger600_count_41025_SB_200532_10621992_GRCh38-2020-A',
#  'cellranger600_count_41025_SB_200532_10621990_GRCh38-2020-A',
#  'cellranger600_count_41025_SB_200532_10621991_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032965_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032967_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032966_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032968_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032964_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032969_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841316_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841317_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841318_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841319_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841320_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297927_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297933_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297922_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297928_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297923_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297929_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297924_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297930_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10
GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254462_GRCh38-2020-A',
#  'cellranger211_count_27023_5478STDY7652318_GRCh38',
#  'cellranger600_count_39102_SB_200532_10297931_GRCh38-2020-A',
#  'spaceranger130_count_43478_SB_200532_12081780_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297933_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297926_GRCh38-2020-A',
#  'c2loc',
#  'cellranger600_count_41025_SB_200532_10621992_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254466_GRCh38-2020-A',
#  'spaceranger130_count_43481_SB_200532_12081774_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018322_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032964_GRCh38-2020-A',
#  'cellranger211_count_29750_5478STDY7980348_GRCh38-1_2_0',
#  'cellranger600_count_37295_SB_200532_10032966_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032969_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018324_GRCh38-2020-A',
#  'cellranger211_count_29750_5478STDY7980349_GRCh38-1_2_0',
#  'cellranger600_count_41456_SB_200532_10863994_GRCh38-2020-A',
#  'spaceranger110_count_34881_WS_F_ADRsp9141993_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018314_GRCh38-2020-A',
#  'WSSS_THYst9699525',
#  'cellranger600_count_44847_SB_200532_12829011_GRCh38-2020-A',
#  'WSSS_THYst9383360',
#  'cellranger600_count_46200_SL_CRTexp13190662_GRCh38-2020-A',
#  'WSSS_THYst9699524',
#  '220724Cartilage.h5ad',
#  'cellranger600_count_41025_SB_200532_10621991_GRCh38-2020-A',
#  'spine_cellxgene.h5ad',
#  'spaceranger110_count_34881_WS_F_ADRsp9141992_GRCh38-2020-A',
#  'cellranger600_count_46200_SL_CRTexp13190660_GRCh38-2020-A',
#  'cellranger211_count_35528_WSSS_THYst9384957_GRCh38-1_2_0',
#  'cellranger600_count_41456_SB_200532_10863993_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032965_GRCh38-2020-A',
#  'cellranger600_count_45703_SL_CRTexp13070416_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297924_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018321_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863986_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297928_GRCh38-2020-A',
#  'cellranger211_count_26155_FCAImmP7536759_GRCh38',
#  'cellranger600_count_46200_SL_CRTexp13190657_GRCh38-2020-A',
#  'spaceranger110_count_34881_WS_F_ADRsp9141994_GRCh38-2020-A',
#  'cellranger211_count_35528_WSSS_THYst9384958_GRCh38-1_2_0',
#  'cellranger600_count_42152_SB_200532_11254459_GRCh38-2020-A',
#  'cellranger600_count_45703_SL_CRTexp13070414_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297923_GRCh38-2020-A',
#  'cellranger600_count_45703_SL_CRTexp13070412_GRCh38-2020-A',
#  'cellranger211_count_26155_FCAImmP7536758_GRCh38',
#  'cellranger600_count_40813_SB_200532_10841320_GRCh38-2020-A',
#  'cellranger600_count_46766_SL_CRTexp13442809_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018315_GRCh38-2020-A',
#  'cellranger600_count_46766_SL_CRTexp13442808_GRCh38-2020-A',
#  'cellranger600_count_44847_SB_200532_12829018_GRCh38-2020-A',
#  'spaceranger130_count_43481_SB_200532_12081775_GRCh38-2020-A',
#  'spaceranger130_count_43481_SB_200532_12081773_GRCh38-2020-A',
#  'cartilage_v2.rds',
#  'cellranger600_count_39102_SB_200532_10297932_GRCh38-2020-A',
#  'spaceranger130_count_43481_SB_200532_12081776_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841323_GRCh38-2020-A',
#  'WSSS_THYst9699523',
#  'cellranger600_count_39102_SB_200532_10297922_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297925_GRCh38-2020-A',
#  'cellranger600_count_45703_SL_CRTexp13070418_GRCh38-2020-A',
#  'cellranger600_count_46766_SL_CRTexp13442804_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863991_GRCh38-2020-A',
#  'cellranger600_count_46200_SL_CRTexp13190655_GRCh38-2020-A',
#  'cellranger600_count_46200_SL_CRTexp13190659_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018318_GRCh38-2020-A',
#  'cellranger600_count_46200_SL_CRTexp13190661_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863989_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018317_GRCh38-2020-A',
#  'cellranger211_count_26155_5386STDY7537944_GRCh38',
#  'cellranger211_count_27370_5478STDY7717492_GRCh38',
#  'cellranger600_count_46766_SL_CRTexp13442810_GRCh38-2020-A',
#  'cellranger600_count_45703_SL_CRTexp13070413_GRCh38-2020-A',
#  'cellranger211_count_27370_5478STDY7717494_GRCh38',
#  'CellRanger',
#  'cartilage_v2.h5ad',
#  'test.txt',
#  'cellranger600_count_40813_SB_200532_10841318_GRCh38-2020-A',
#  'cellranger600_count_44847_SB_200532_12829013_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018323_GRCh38-2020-A',
#  'cellranger600_count_44847_SB_200532_12829015_GRCh38-2020-A',
#  'cellranger600_count_44847_SB_200532_12829017_GRCh38-2020-A',
#  'cellranger211_count_35528_WSSS_THYst9384953_GRCh38-1_2_0',
#  'cellranger600_count_37295_SB_200532_10032968_GRCh38-2020-A',
#  'cellranger600_count_46766_SL_CRTexp13442806_GRCh38-2020-A',
#  'cellranger211_count_27370_5478STDY7717491_GRCh38',
#  'cellranger600_count_40813_SB_200532_10841316_GRCh38-2020-A',
#  'cellranger600_count_46200_SL_CRTexp13190656_GRCh38-2020-A',
#  'cellranger600_count_44847_SB_200532_12829016_GRCh38-2020-A',
#  'cellranger600_count_45703_SL_CRTexp13070417_GRCh38-2020-A']

# %%
filter_data = [x for x in arr if
              any(y in x for y in sample_list)]

# %%
sample_list
# Out:
# ['cellranger600_count_40813_SB_200532_10841321_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841322_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841323_GRCh38-2020-A',
#  'cellranger600_count_41025_SB_200532_10621989_GRCh38-2020-A',
#  'cellranger600_count_41025_SB_200532_10621992_GRCh38-2020-A',
#  'cellranger600_count_41025_SB_200532_10621990_GRCh38-2020-A',
#  'cellranger600_count_41025_SB_200532_10621991_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032965_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032967_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032966_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032968_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032964_GRCh38-2020-A',
#  'cellranger600_count_37295_SB_200532_10032969_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841316_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841317_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841318_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841319_GRCh38-2020-A',
#  'cellranger600_count_40813_SB_200532_10841320_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297927_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297933_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297922_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297928_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297923_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297929_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297924_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297930_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297925_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297931_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297926_GRCh38-2020-A',
#  'cellranger600_count_39102_SB_200532_10297932_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254458_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254463_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254461_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254466_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254462_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254467_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254459_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254464_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254460_GRCh38-2020-A',
#  'cellranger600_count_42152_SB_200532_11254465_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863985_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863991_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863988_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863994_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863989_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863995_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863986_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863992_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863987_GRCh38-2020-A',
#  'cellranger600_count_41456_SB_200532_10863993_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018313_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018314_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018315_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018316_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018317_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018318_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018319_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018320_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018321_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018322_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018323_GRCh38-2020-A',
#  'cellranger600_count_41865_SB_200532_11018324_GRCh38-2020-A']

# %%
len(filter_data)

# %%
adata, ad_list = read_10x_output(
    smp_list=filter_data,
    
    type='filtered'
)
# Out:
# /home/jovyan/my-conda-envs/WE/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/jovyan/my-conda-envs/WE/lib/python3.9/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
pwd
# Out:
# '/lustre/scratch126/cellgen/team205/jl29/samsidfetal/samsidfetal'

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 559455 × 36601
#     obs: 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'mt_frac', 'sample_id', 'barcode'
#     var: 'feature_types', 'genome', 'SYMBOL', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'mt'

# %%
adata.var
# Out:
#                    feature_types  genome       SYMBOL  n_cells_by_counts  \
# ENSEMBL
# ENSG00000243485  Gene Expression  GRCh38  MIR1302-2HG                  0
# ENSG00000237613  Gene Expression  GRCh38      FAM138A                  0
# ENSG00000186092  Gene Expression  GRCh38        OR4F5                  0
# ENSG00000238009  Gene Expression  GRCh38   AL627309.1                 10
# ENSG00000239945  Gene Expression  GRCh38   AL627309.3                  0
# ...                          ...     ...          ...                ...
# ENSG00000277836  Gene Expression  GRCh38   AC141272.1                  0
# ENSG00000278633  Gene Expression  GRCh38   AC023491.2                  0
# ENSG00000276017  Gene Expression  GRCh38   AC007325.1                  0
# ENSG00000278817  Gene Expression  GRCh38   AC007325.4                108
# ENSG00000277196  Gene Expression  GRCh38   AC007325.2                  1
#
#                  mean_counts  log1p_mean_counts  pct_dropout_by_counts  \
# ENSEMBL
# ENSG00000243485     0.000000           0.000000             100.000000
# ENSG00000237613     0.000000           0.000000             100.000000
# ENSG00000186092     0.000000           0.000000             100.000000
# ENSG00000238009     0.005900           0.005882              99.410029
# ENSG00000239945     0.000000           0.000000             100.000000
# ...                      ...                ...                    ...
# ENSG00000277836     0.000000           0.000000             100.000000
# ENSG00000278633     0.000000           0.000000             100.000000
# ENSG00000276017     0.000000           0.000000             100.000000
# ENSG00000278817     0.077286           0.074445              93.628319
# ENSG00000277196     0.000590           0.000590              99.941003
#
#                  total_counts  log1p_total_counts     mt
# ENSEMBL
# ENSG00000243485           0.0            0.000000  False
# ENSG00000237613           0.0            0.000000  False
# ENSG00000186092           0.0            0.000000  False
# ENSG00000238009          10.0            2.397895  False
# ENSG00000239945           0.0            0.000000  False
# ...                       ...                 ...    ...
# ENSG00000277836           0.0            0.000000  False
# ENSG00000278633           0.0            0.000000  False
# ENSG00000276017           0.0            0.000000  False
# ENSG00000278817         131.0            4.882802  False
# ENSG00000277196           1.0            0.693147  False
#
# [36601 rows x 10 columns]

# %% [markdown]
# # Metadata

# %%
metadata= pd.read_csv("/home/jovyan/mount/gdrive/Spine/metadata_spine_DRteam.csv")

# %%
metadata["run_id"]= metadata["irods_path"]

# %%
metadata
# Out:
#     PCW    region subregion dissociation      batch  \
# 0   7.0    lumbar  cervical   no_trypsin  HDBR15918
# 1   7.0  thoracic  thoracic   no_trypsin  HDBR15918
# 2   7.0  cervical    lumbar   no_trypsin  HDBR15918
# 3   5.0  cervical  cervical   no_trypsin  HDBR15868
# 4   5.0  cervical  cervical      trypsin  HDBR15868
# ..  ...       ...       ...          ...        ...
# 63  NaN       NaN       NaN          NaN        NaN
# 64  NaN       NaN       NaN          NaN        NaN
# 65  NaN       NaN       NaN          NaN        NaN
# 66  NaN       NaN       NaN          NaN        NaN
# 67  NaN       NaN       NaN          NaN        NaN
#
#                                            irods_path  \
# 0   cellranger600_count_40813_SB_200532_10841321_G...
# 1   cellranger600_count_40813_SB_200532_10841322_G...
# 2   cellranger600_count_40813_SB_200532_10841323_G...
# 3   cellranger600_count_41025_SB_200532_10621989_G...
# 4   cellranger600_count_41025_SB_200532_10621992_G...
# ..                                                ...
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
#
#                                                run_id
# 0   cellranger600_count_40813_SB_200532_10841321_G...
# 1   cellranger600_count_40813_SB_200532_10841322_G...
# 2   cellranger600_count_40813_SB_200532_10841323_G...
# 3   cellranger600_count_41025_SB_200532_10621989_G...
# 4   cellranger600_count_41025_SB_200532_10621992_G...
# ..                                                ...
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
#
# [68 rows x 7 columns]

# %%
metadata=metadata.dropna(how='all')

# %%
metadata
# Out:
#      PCW     region subregion dissociation      batch  \
# 0    7.0     lumbar  cervical   no_trypsin  HDBR15918
# 1    7.0   thoracic  thoracic   no_trypsin  HDBR15918
# 2    7.0   cervical    lumbar   no_trypsin  HDBR15918
# 3    5.0   cervical  cervical   no_trypsin  HDBR15868
# 4    5.0   cervical  cervical      trypsin  HDBR15868
# ..   ...        ...       ...          ...        ...
# 57  17.0   cervical       NaN      trypsin  HDBR15948
# 58  17.0  thoracic        NaN      trypsin  HDBR15948
# 59  17.0   thoracic       NaN      trypsin  HDBR15948
# 60  17.0     lumbar       NaN      trypsin  HDBR15948
# 61  17.0     sacral       NaN      trypsin  HDBR15948
#
#                                            irods_path  \
# 0   cellranger600_count_40813_SB_200532_10841321_G...
# 1   cellranger600_count_40813_SB_200532_10841322_G...
# 2   cellranger600_count_40813_SB_200532_10841323_G...
# 3   cellranger600_count_41025_SB_200532_10621989_G...
# 4   cellranger600_count_41025_SB_200532_10621992_G...
# ..                                                ...
# 57  cellranger600_count_41865_SB_200532_11018320_G...
# 58  cellranger600_count_41865_SB_200532_11018321_G...
# 59  cellranger600_count_41865_SB_200532_11018322_G...
# 60  cellranger600_count_41865_SB_200532_11018323_G...
# 61  cellranger600_count_41865_SB_200532_11018324_G...
#
#                                                run_id
# 0   cellranger600_count_40813_SB_200532_10841321_G...
# 1   cellranger600_count_40813_SB_200532_10841322_G...
# 2   cellranger600_count_40813_SB_200532_10841323_G...
# 3   cellranger600_count_41025_SB_200532_10621989_G...
# 4   cellranger600_count_41025_SB_200532_10621992_G...
# ..                                                ...
# 57  cellranger600_count_41865_SB_200532_11018320_G...
# 58  cellranger600_count_41865_SB_200532_11018321_G...
# 59  cellranger600_count_41865_SB_200532_11018322_G...
# 60  cellranger600_count_41865_SB_200532_11018323_G...
# 61  cellranger600_count_41865_SB_200532_11018324_G...
#
# [62 rows x 7 columns]

# %%
adata.obs.dtypes
# Out:
# n_genes_by_counts              object
# log1p_n_genes_by_counts        object
# total_counts                   object
# log1p_total_counts             object
# pct_counts_in_top_50_genes     object
# pct_counts_in_top_100_genes    object
# pct_counts_in_top_200_genes    object
# pct_counts_in_top_500_genes    object
# mt_frac                        object
# sample_id                      object
# barcode                        object
# dtype: object

# %%
#Add cleaned metadata to the Anndata.obs table
        # obs_merged = pd.merge(left = adata.obs, right = metadata, 
        #                      how = "left", left_on="sample", right_on="sample")
        # obs_merged.index = obs_merged['sample']+"_"+obs_merged['barcode']
        # print(obs_merged.index.equals(adata.obs.index))
        # adata.obs = obs_merged

# %%
metadata["run_id"]= metadata["run_id"].astype(str)
adata.obs["sample_id"]=adata.obs["sample_id"].astype(str)
# Out:
# /tmp/ipykernel_1418/2838179719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata["run_id"]= metadata["run_id"].astype(str)

# %%
metadata
# Out:
#      PCW     region subregion dissociation      batch  \
# 0    7.0     lumbar  cervical   no_trypsin  HDBR15918
# 1    7.0   thoracic  thoracic   no_trypsin  HDBR15918
# 2    7.0   cervical    lumbar   no_trypsin  HDBR15918
# 3    5.0   cervical  cervical   no_trypsin  HDBR15868
# 4    5.0   cervical  cervical      trypsin  HDBR15868
# ..   ...        ...       ...          ...        ...
# 57  17.0   cervical       NaN      trypsin  HDBR15948
# 58  17.0  thoracic        NaN      trypsin  HDBR15948
# 59  17.0   thoracic       NaN      trypsin  HDBR15948
# 60  17.0     lumbar       NaN      trypsin  HDBR15948
# 61  17.0     sacral       NaN      trypsin  HDBR15948
#
#                                            irods_path  \
# 0   cellranger600_count_40813_SB_200532_10841321_G...
# 1   cellranger600_count_40813_SB_200532_10841322_G...
# 2   cellranger600_count_40813_SB_200532_10841323_G...
# 3   cellranger600_count_41025_SB_200532_10621989_G...
# 4   cellranger600_count_41025_SB_200532_10621992_G...
# ..                                                ...
# 57  cellranger600_count_41865_SB_200532_11018320_G...
# 58  cellranger600_count_41865_SB_200532_11018321_G...
# 59  cellranger600_count_41865_SB_200532_11018322_G...
# 60  cellranger600_count_41865_SB_200532_11018323_G...
# 61  cellranger600_count_41865_SB_200532_11018324_G...
#
#                                                run_id
# 0   cellranger600_count_40813_SB_200532_10841321_G...
# 1   cellranger600_count_40813_SB_200532_10841322_G...
# 2   cellranger600_count_40813_SB_200532_10841323_G...
# 3   cellranger600_count_41025_SB_200532_10621989_G...
# 4   cellranger600_count_41025_SB_200532_10621992_G...
# ..                                                ...
# 57  cellranger600_count_41865_SB_200532_11018320_G...
# 58  cellranger600_count_41865_SB_200532_11018321_G...
# 59  cellranger600_count_41865_SB_200532_11018322_G...
# 60  cellranger600_count_41865_SB_200532_11018323_G...
# 61  cellranger600_count_41865_SB_200532_11018324_G...
#
# [62 rows x 7 columns]

# %%
metadata.dtypes
# Out:
# PCW             float64
# region           object
# subregion        object
# dissociation     object
# batch            object
# irods_path       object
# run_id           object
# dtype: object

# %%
#metadata.reset_index(drop=True)
obs_merged = pd.merge(left = metadata, right = adata.obs, 
                             how = "left", left_on="run_id", right_on="sample_id")
# obs_merged.index = obs_merged['sample_id']+"_"+obs_merged['barcode']
# print(obs_merged.index.equals(adata.obs.index))
# adata.obs = obs_merged

# %%
obs_merged
# Out:
#                                                      PCW  region subregion  \
# cellranger600_count_40813_SB_200532_10841321_GR...   7.0  lumbar  cervical
# cellranger600_count_40813_SB_200532_10841321_GR...   7.0  lumbar  cervical
# cellranger600_count_40813_SB_200532_10841321_GR...   7.0  lumbar  cervical
# cellranger600_count_40813_SB_200532_10841321_GR...   7.0  lumbar  cervical
# cellranger600_count_40813_SB_200532_10841321_GR...   7.0  lumbar  cervical
# ...                                                  ...     ...       ...
# cellranger600_count_41865_SB_200532_11018324_GR...  17.0  sacral       NaN
# cellranger600_count_41865_SB_200532_11018324_GR...  17.0  sacral       NaN
# cellranger600_count_41865_SB_200532_11018324_GR...  17.0  sacral       NaN
# cellranger600_count_41865_SB_200532_11018324_GR...  17.0  sacral       NaN
# cellranger600_count_41865_SB_200532_11018324_GR...  17.0  sacral       NaN
#
#                                                    dissociation      batch  \
# cellranger600_count_40813_SB_200532_10841321_GR...   no_trypsin  HDBR15918
# cellranger600_count_40813_SB_200532_10841321_GR...   no_trypsin  HDBR15918
# cellranger600_count_40813_SB_200532_10841321_GR...   no_trypsin  HDBR15918
# cellranger600_count_40813_SB_200532_10841321_GR...   no_trypsin  HDBR15918
# cellranger600_count_40813_SB_200532_10841321_GR...   no_trypsin  HDBR15918
# ...                                                         ...        ...
# cellranger600_count_41865_SB_200532_11018324_GR...      trypsin  HDBR15948
# cellranger600_count_41865_SB_200532_11018324_GR...      trypsin  HDBR15948
# cellranger600_count_41865_SB_200532_11018324_GR...      trypsin  HDBR15948
# cellranger600_count_41865_SB_200532_11018324_GR...      trypsin  HDBR15948
# cellranger600_count_41865_SB_200532_11018324_GR...      trypsin  HDBR15948
#
#                                                                                            irods_path  \
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# ...                                                                                               ...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
#
#                                                                                                run_id  \
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# ...                                                                                               ...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
#
#                                                    n_genes_by_counts  \
# cellranger600_count_40813_SB_200532_10841321_GR...               466
# cellranger600_count_40813_SB_200532_10841321_GR...              1006
# cellranger600_count_40813_SB_200532_10841321_GR...              1862
# cellranger600_count_40813_SB_200532_10841321_GR...              1166
# cellranger600_count_40813_SB_200532_10841321_GR...               617
# ...                                                              ...
# cellranger600_count_41865_SB_200532_11018324_GR...              1216
# cellranger600_count_41865_SB_200532_11018324_GR...               701
# cellranger600_count_41865_SB_200532_11018324_GR...              2226
# cellranger600_count_41865_SB_200532_11018324_GR...              1442
# cellranger600_count_41865_SB_200532_11018324_GR...              1508
#
#                                                    log1p_n_genes_by_counts  \
# cellranger600_count_40813_SB_200532_10841321_GR...      6.1463292576688975
# cellranger600_count_40813_SB_200532_10841321_GR...       6.914730892718563
# cellranger600_count_40813_SB_200532_10841321_GR...       7.529943370601589
# cellranger600_count_40813_SB_200532_10841321_GR...       7.062191632286556
# cellranger600_count_40813_SB_200532_10841321_GR...        6.42648845745769
# ...                                                                    ...
# cellranger600_count_41865_SB_200532_11018324_GR...       7.104144092987527
# cellranger600_count_41865_SB_200532_11018324_GR...       6.553933404025811
# cellranger600_count_41865_SB_200532_11018324_GR...       7.708410667257367
# cellranger600_count_41865_SB_200532_11018324_GR...       7.274479558773871
# cellranger600_count_41865_SB_200532_11018324_GR...       7.319202458767849
#
#                                                    total_counts  \
# cellranger600_count_40813_SB_200532_10841321_GR...        900.0
# cellranger600_count_40813_SB_200532_10841321_GR...       2392.0
# cellranger600_count_40813_SB_200532_10841321_GR...       5188.0
# cellranger600_count_40813_SB_200532_10841321_GR...       2368.0
# cellranger600_count_40813_SB_200532_10841321_GR...       1024.0
# ...                                                         ...
# cellranger600_count_41865_SB_200532_11018324_GR...       2048.0
# cellranger600_count_41865_SB_200532_11018324_GR...       1384.0
# cellranger600_count_41865_SB_200532_11018324_GR...       5599.0
# cellranger600_count_41865_SB_200532_11018324_GR...       3001.0
# cellranger600_count_41865_SB_200532_11018324_GR...       2814.0
#
#                                                    log1p_total_counts  \
# cellranger600_count_40813_SB_200532_10841321_GR...          6.8035054
# cellranger600_count_40813_SB_200532_10841321_GR...           7.780303
# cellranger600_count_40813_SB_200532_10841321_GR...          8.5542965
# cellranger600_count_40813_SB_200532_10841321_GR...           7.770223
# cellranger600_count_40813_SB_200532_10841321_GR...           6.932448
# ...                                                               ...
# cellranger600_count_41865_SB_200532_11018324_GR...          7.6251073
# cellranger600_count_41865_SB_200532_11018324_GR...          7.2334557
# cellranger600_count_41865_SB_200532_11018324_GR...           8.630522
# cellranger600_count_41865_SB_200532_11018324_GR...           8.007034
# cellranger600_count_41865_SB_200532_11018324_GR...           68.61046317894035
# cellranger600_count_41865_SB_200532_11018324_GR...           64.17910447761194
#
#                                                    mt_frac  \
# cellranger600_count_40813_SB_200532_10841321_GR...     0.0
# cellranger600_count_40813_SB_200532_10841321_GR...     0.0
# cellranger600_count_40813_SB_200532_10841321_GR...     0.0
# cellranger600_count_40813_SB_200532_10841321_GR...     0.0
# cellranger600_count_40813_SB_200532_10841321_GR...     0.0
# ...                                                    ...
# cellranger600_count_41865_SB_200532_11018324_GR...     0.0
# cellranger600_count_41865_SB_200532_11018324_GR...     0.0
# cellranger600_count_41865_SB_200532_11018324_GR...     0.0
# cellranger600_count_41865_SB_200532_11018324_GR...     0.0
# cellranger600_count_41865_SB_200532_11018324_GR...     0.0
#
#                                                                                             sample_id  \
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# cellranger600_count_40813_SB_200532_10841321_GR...  cellranger600_count_40813_SB_200532_10841321_G...
# ...                                                                                               ...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
# cellranger600_count_41865_SB_200532_11018324_GR...  cellranger600_count_41865_SB_200532_11018324_G...
#
#                                                                barcode
# cellranger600_count_40813_SB_200532_10841321_GR...  AAACCCAAGAAGCTGC-1
# cellranger600_count_40813_SB_200532_10841321_GR...  AAACCCAAGAGATGCC-1
# cellranger600_count_40813_SB_200532_10841321_GR...  AAACCCAAGAGTTCGG-1
# cellranger600_count_40813_SB_200532_10841321_GR...  AAACCCAAGATTCGCT-1
# cellranger600_count_40813_SB_200532_10841321_GR...  AAACCCAAGCGTCTGC-1
# ...                                                                ...
# cellranger600_count_41865_SB_200532_11018324_GR...  TTTGTTGTCGCCTATC-1
# cellranger600_count_41865_SB_200532_11018324_GR...  TTTGTTGTCGGAATGG-1
# cellranger600_count_41865_SB_200532_11018324_GR...  TTTGTTGTCGGCCAAC-1
# cellranger600_count_41865_SB_200532_11018324_GR...  TTTGTTGTCTCATGGA-1
# cellranger600_count_41865_SB_200532_11018324_GR...  TTTGTTGTCTGCCCTA-1
#
# [559455 rows x 18 columns]

# %%
adata.obs.index
# Out:
# Index(['cellranger600_count_40813_SB_200532_10841321_GRCh38-2020-A_AAACCCAAGAAGCTGC-1',
#        'cellranger600_count_40813_SB_200532_10841321_GRCh38-2020-A_AAACCCAAGAGATGCC-1',
#        'cellranger600_count_40813_SB_200532_10841321_GRCh38-2020-A_AAACCCAAGAGTTCGG-1',
#        'cellranger600_count_40813_SB_200532_10841321_GRCh38-2020-A_AAACCCAAGATTCGCT-1',
#        'cellranger600_count_40813_SB_200532_10841321_GRCh38-2020-A_AAACCCAAGCGTCTGC-1',
#        'cellranger600_count_40813_SB_200532_10841321_GRCh38-2020-A_AAACCCAAGGAGAGTA-1',
#        'cellranger600_count_40813_SB_200532_10841321_GRCh38-2020-A_AAACCCAAGGCAGGTT-1',
#        'cellranger600_count_40813_SB_200532_10841321_GRCh38-2020-A_AAACCCAAGGCCTGAA-1',
#        'cellranger600_count_40813_SB_200532_10841321_GRCh38-2020-A_AAACCCAAGTAATCCC-1',
#        'cellranger600_count_40813_SB_200532_10841321_GRCh38-2020-A_AAACCCACACAATTCG-1',
#        ...
#        'cellranger600_count_41865_SB_200532_11018324_GRCh38-2020-A_TTTGTTGGTGCAACGA-1',
#        'cellranger600_count_41865_SB_200532_11018324_GRCh38-2020-A_TTTGTTGGTGTTCAGT-1',
#        'cellranger600_count_41865_SB_200532_11018324_GRCh38-2020-A_TTTGTTGGTTCGTACA-1',
#        'cellranger600_count_41865_SB_200532_11018324_GRCh38-2020-A_TTTGTTGGTTGCTCAA-1',
#        'cellranger600_count_41865_SB_200532_11018324_GRCh38-2020-A_TTTGTTGTCCAACACA-1',
#        'cellranger600_count_41865_SB_200532_11018324_GRCh38-2020-A_TTTGTTGTCGCCTATC-1',
#        'cellranger600_count_41865_SB_200532_11018324_GRCh38-2020-A_TTTGTTGTCGGAATGG-1',
#        'cellranger600_count_41865_SB_200532_11018324_GRCh38-2020-A_TTTGTTGTCGGCCAAC-1',
#        'cellranger600_count_41865_SB_200532_11018324_GRCh38-2020-A_TTTGTTGTCTCATGGA-1',
#        'cellranger600_count_41865_SB_200532_11018324_GRCh38-2020-A_TTTGTTGTCTGCCCTA-1'],
#       dtype='object', length=559455)

# %%
obs_merged.index = obs_merged['sample_id']+"_"+obs_merged['barcode']
print(obs_merged.index.equals(adata.obs.index))
adata.obs = obs_merged
# Out:
# False

# %%
adata.write_h5ad("/lustre/scratch126/cellgen/team298/sm54/Data_Integration/Spine/data/raw_counts_no_ppc_5_17_pcw.h5ad")

# %%
adata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 adata
#
# NameError: name 'adata' is not defined

# %%
sc.read_cellranger-arc201_count_49263c3c9ece1e019faa5bbb4533af77
