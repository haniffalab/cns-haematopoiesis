# %%
import scanpy as sc

# %%
adata= sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/tickets/tic-3721/work/scAutoQC/scautoqc-results-hemato_v1/scautoqc_pooled.h5ad')

# %%
adata.obs['pass_default'].value_counts()
# Out:
# pass_default
# True     5385697
# False     912887
# Name: count, dtype: int64

# %%
adata.obs['suo22_pred'].value_counts()
# Out:
# suo22_pred
# NEURON                             2439220
# FIBROBLAST_I                        366335
# CHONDROCYTE                         268895
# LATE_ERY                            250967
# GLIAL                               181749
#                                     ...
# DC_PROGENITOR                           64
# PRE_DC2                                 61
# DOUBLET_ENDOTHELIUM_ERYTHROCYTE         52
# LANGERHANS_CELLS                        25
# DOUBLET_ERY_B                           17
# Name: count, Length: 135, dtype: int64

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6298584 × 36601
# ...

# %%
adata.obs['pass_auto_filter'].value_counts()
# Out:
# pass_auto_filter
# 20     5227021
# 100    1035728
# 50       31508
# 80        4327
# Name: count, dtype: int64

# %%
adata.obs.to
# Out:
#                                   cell_probability  droplet_efficiency  \
# AAACCTGAGAGAACAG-10X101_1                 0.999955            1.191442
# AAACCTGAGAGAGCTC-10X101_1                 0.999955            1.323962
# AAACCTGAGGCTCAGA-10X101_1                 0.999968            0.841026
# AAACCTGAGTAATCCC-10X101_1                 0.999908            0.892734
# AAACCTGCACGGTTTA-10X101_1                 0.999955            2.231103
# ...                                            ...                 ...
# TTTGTCAGTGCGGTAA-WS_wEMB13942153          0.999687            1.157075
# TTTGTCAGTGTATGGG-WS_wEMB13942153          0.999954            1.218015
# TTTGTCATCATAAAGG-WS_wEMB13942153          0.999981            1.095010
# TTTGTCATCCAAAGTC-WS_wEMB13942153          0.999955            1.423648
# TTTGTCATCGGGAGTA-WS_wEMB13942153          1.000000            0.840884
#
#                                    cecilia22_predH  cecilia22_predH_prob  \
# ...

# %%
adata.obs.to_csv("/nfs/team298/sm54/BoneAtlasProject/metadata/cell_metadata/adata_scautoqc_obs.csv", index=True)
